# %% [markdown]
# # ELECTRONIC MUSIC GENRE CLASSIFICATION

# %% [markdown]
# ### Create PySpark instance

# %%
import findspark
findspark.init()

import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Multiclass Classification").getOrCreate()

cores = spark._jsc.sc().getExecutorMemoryStatus().keySet().size()
print("You are working with", cores, "core(s)")
spark
# Out:
# You are working with 1 core(s)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-K5FG320:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Multiclzass Classification</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Import the dataset and others librairies

# %%
# Dataset
df = spark.read.csv('beatsdataset.csv', inferSchema = True, header = True)

# Librairies
import pandas as pd

from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler, MinMaxScaler, RegexTokenizer, StopWordsRemover, CountVectorizer

from pyspark.sql.types import * 
from pyspark.sql.functions import *

from pyspark.ml.classification import *

from pyspark.ml.evaluation import *

from pyspark.ml import Pipeline

from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %% [markdown]
# ### Data Preparation

# %%
pd.DataFrame(df.take(5), columns=df.columns)
# Out:
#    _c0    1-ZCRm  2-Energym  3-EnergyEntropym  4-SpectralCentroidm  \
# 0    0  0.136440   0.088861          3.201201             0.262825
# 1    1  0.117039   0.108389          3.194001             0.247657
# 2    2  0.085308   0.128525          3.123837             0.217205
# 3    3  0.103050   0.167042          3.150830             0.233593
# 4    4  0.151730   0.148405          3.194498             0.293730
#
#    5-SpectralSpreadm  6-SpectralEntropym  7-SpectralFluxm  8-SpectralRolloffm  \
# 0           0.249212            1.114423         0.007003            0.256682
# 1           0.250288            1.065668         0.005387            0.199821
# 2           0.228652            0.789647         0.008247            0.156822
# 3           0.245032            0.967082         0.006571            0.168083
# 4           0.267231            1.353005         0.003872            0.292055
#
#    9-MFCCs1m  ...  63-ChromaVector8std  64-ChromaVector9std  \
# 0 -22.723259  ...             0.003431             0.004981
# 1 -21.775871  ...             0.004461             0.006441
# 2 -22.472722  ...             0.001529             0.004556
# 3 -21.470751  ...             0.001591             0.003514
# 4 -21.371157  ...             0.003945             0.004131
#
#    65-ChromaVector10std  66-ChromaVector11std  67-ChromaVector12std  \
# 0              0.010818              0.024001              0.005201
# 1              0.007469              0.015499              0.005589
# 2              0.007723              0.017482              0.002901
# 3              0.009477              0.023162              0.004165
# 4              0.011330              0.028188              0.002639
#
#    68-ChromaDeviationstd      69-BPM  70-BPMconf  71-BPMessentia    class
# 0               0.015056  133.333333    0.132792           128.0  BigRoom
# 1               0.019339  120.000000    0.112767           126.0  BigRoom
# 2               0.022201  133.333333    0.123373           129.0  BigRoom
# 3               0.015379  133.333333    0.158876           129.0  BigRoom
# 4               0.019079  133.333333    0.190708           129.0  BigRoom
#
# [5 rows x 73 columns]

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- 1-ZCRm: double (nullable = true)
#  |-- 2-Energym: double (nullable = true)
#  |-- 3-EnergyEntropym: double (nullable = true)
#  |-- 4-SpectralCentroidm: double (nullable = true)
#  |-- 5-SpectralSpreadm: double (nullable = true)
#  |-- 6-SpectralEntropym: double (nullable = true)
#  |-- 7-SpectralFluxm: double (nullable = true)
#  |-- 8-SpectralRolloffm: double (nullable = true)
#  |-- 9-MFCCs1m: double (nullable = true)
#  |-- 10-MFCCs2m: double (nullable = true)
#  |-- 11-MFCCs3m: double (nullable = true)
#  |-- 12-MFCCs4m: double (nullable = true)
#  |-- 13-MFCCs5m: double (nullable = true)
#  |-- 14-MFCCs6m: double (nullable = true)
#  |-- 15-MFCCs7m: double (nullable = true)
#  |-- 16-MFCCs8m: double (nullable = true)
#  |-- 17-MFCCs9m: double (nullable = true)
#  |-- 18-MFCCs10m: double (nullable = true)
#  |-- 19-MFCCs11m: double (nullable = true)
#  |-- 20-MFCCs12m: double (nullable = true)
#  |-- 21-MFCCs13m: double (nullable = true)
#  |-- 22-ChromaVector1m: double (nullable = true)
#  |-- 23-ChromaVector2m: double (nullable = true)
#  |-- 24-ChromaVector3m: double (nullable = true)
#  |-- 25-ChromaVector4m: double (nullable = true)
#  |-- 26-ChromaVector5m: double (nullable = true)
#  |-- 27-ChromaVector6m: double (nullable = true)
#  |-- 28-ChromaVector7m: double (nullable = true)
#  |-- 29-ChromaVector8m: double (nullable = true)
#  |-- 30-ChromaVector9m: double (nullable = true)
#  |-- 31-ChromaVector10m: double (nullable = true)
#  |-- 32-ChromaVector11m: double (nullable = true)
#  |-- 33-ChromaVector12m: double (nullable = true)
#  |-- 34-ChromaDeviationm: double (nullable = true)
#  |-- 35-ZCRstd: double (nullable = true)
#  |-- 36-Energystd: double (nullable = true)
#  |-- 37-EnergyEntropystd: double (nullable = true)
#  |-- 38-SpectralCentroidstd: double (nullable = true)
#  |-- 39-SpectralSpreadstd: double (nullable = true)
#  |-- 40-SpectralEntropystd: double (nullable = true)
#  |-- 41-SpectralFluxstd: double (nullable = true)
#  |-- 42-SpectralRolloffstd: double (nullable = true)
#  |-- 43-MFCCs1std: double (nullable = true)
#  |-- 44-MFCCs2std: double (nullable = true)
#  |-- 45-MFCCs3std: double (nullable = true)
#  |-- 46-MFCCs4std: double (nullable = true)
#  |-- 47-MFCCs5std: double (nullable = true)
#  |-- 48-MFCCs6std: double (nullable = true)
#  |-- 49-MFCCs7std: double (nullable = true)
#  |-- 50-MFCCs8std: double (nullable = true)
#  |-- 51-MFCCs9std: double (nullable = true)
#  |-- 52-MFCCs10std: double (nullable = true)
#  |-- 53-MFCCs11std: double (nullable = true)
#  |-- 54-MFCCs12std: double (nullable = true)
#  |-- 55-MFCCs13std: double (nullable = true)
#  |-- 56-ChromaVector1std: double (nullable = true)
#  |-- 57-ChromaVector2std: double (nullable = true)
#  |-- 58-ChromaVector3std: double (nullable = true)
#  |-- 59-ChromaVector4std: double (nullable = true)
#  |-- 60-ChromaVector5std: double (nullable = true)
#  |-- 61-ChromaVector6std: double (nullable = true)
#  |-- 62-ChromaVector7std: double (nullable = true)
#  |-- 63-ChromaVector8std: double (nullable = true)
#  |-- 64-ChromaVector9std: double (nullable = true)
#  |-- 65-ChromaVector10std: double (nullable = true)
#  |-- 66-ChromaVector11std: double (nullable = true)
#  |-- 67-ChromaVector12std: double (nullable = true)
#  |-- 68-ChromaDeviationstd: double (nullable = true)
#  |-- 69-BPM: double (nullable = true)
#  |-- 70-BPMconf: double (nullable = true)
#  |-- 71-BPMessentia: double (nullable = true)
#  |-- class: string (nullable = true)

# %%
# df = df.drop('_c0')
# cols = df.columns

# %%
### Check number of classes
df.groupBy("class").count().show(100, truncate = False)
# Out:
# +--------------------+-----+
# |class               |count|
# +--------------------+-----+
# |PsyTrance           |100  |
# |HardDance           |100  |
# |Breaks              |100  |
# |HardcoreHardTechno  |100  |
# |IndieDanceNuDisco   |100  |
# |Trance              |100  |
# |DeepHouse           |100  |
# |ElectronicaDowntempo|100  |
# |ReggaeDub           |100  |
# |Minimal             |100  |
# |DrumAndBass         |100  |
# |Dubstep             |100  |
# |BigRoom             |100  |
# |Techno              |100  |
# |House               |100  |
# |FutureHouse         |100  |
# |ElectroHouse        |100  |
# |GlitchHop           |100  |
# |TechHouse           |100  |
# |HipHop              |100  |
# |FunkRAndB           |100  |
# |Dance               |100  |
# |ProgressiveHouse    |100  |
# +--------------------+-----+

# %%
# Data Prep function
def MLClassifierDFPrep(df, input_columns, dependent_var, treat_outliers = True, treat_neg_values = True):
    
    # change label (class variable) to string type to prep for reindexing
    # Pyspark is expecting a zero indexed integer for the label column. 
    # Just incase our data is not in that format... we will treat it by using the StringIndexer built in method
    renamed = df.withColumn("label_str", df[dependent_var].cast(StringType())) #Rename and change to string type
    indexer = StringIndexer(inputCol = "label_str", outputCol = "label") #Pyspark is expecting the this naming convention 
    indexed = indexer.fit(renamed).transform(renamed)
    print(indexed.groupBy("class", "label").count().show(100))

    # Convert all string type data in the input column list to numeric
    # Otherwise the Algorithm will not be able to process it
    numeric_inputs = []
    string_inputs = []
    for column in input_columns:
        if str(indexed.schema[column].dataType) == 'StringType':
            indexer = StringIndexer(inputCol=column, outputCol=column+"_num") 
            indexed = indexer.fit(indexed).transform(indexed)
            new_col_name = column+"_num"
            string_inputs.append(new_col_name)
        else:
            numeric_inputs.append(column)
            
    if treat_outliers == True:
        print("We are correcting for non normality now!")
        # empty dictionary d
        d = {}
        # Create a dictionary of quantiles
        for col in numeric_inputs: 
            d[col] = indexed.approxQuantile(col,[0.01,0.99],0.25) #if you want to make it go faster increase the last number
        #Now fill in the values
        for col in numeric_inputs:
            skew = indexed.agg(skewness(indexed[col])).collect() #check for skewness
            skew = skew[0][0]
            # This function will floor, cap and then log+1 (just in case there are 0 values)
            if skew > 1:
                indexed = indexed.withColumn(col, \
                log(when(df[col] < d[col][0],d[col][0])\
                .when(indexed[col] > d[col][1], d[col][1])\
                .otherwise(indexed[col] ) +1).alias(col))
                print(col+" has been treated for positive (right) skewness. (skew =)",skew,")")
            elif skew < -1:
                indexed = indexed.withColumn(col, \
                exp(when(df[col] < d[col][0],d[col][0])\
                .when(indexed[col] > d[col][1], d[col][1])\
                .otherwise(indexed[col] )).alias(col))
                print(col+" has been treated for negative (left) skewness. (skew =",skew,")")

            
    # Produce a warning if there are negative values in the dataframe that Naive Bayes cannot be used. 
    # Note: we only need to check the numeric input values since anything that is indexed won't have negative values
    minimums = df.select([min(c).alias(c) for c in df.columns if c in numeric_inputs]) # Calculate the mins for all columns in the df
    min_array = minimums.select(array(numeric_inputs).alias("mins")) # Create an array for all mins and select only the input cols
    df_minimum = min_array.select(array_min(min_array.mins)).collect() # Collect golobal min as Python object
    df_minimum = df_minimum[0][0] # Slice to get the number itself

    features_list = numeric_inputs + string_inputs
    assembler = VectorAssembler(inputCols=features_list,outputCol='features')
    output = assembler.transform(indexed).select('features','label')

#     final_data = output.select('features','label') #drop everything else
    
    # Now check for negative values and ask user if they want to correct that? 
    if df_minimum < 0:
        print(" ")
        print("WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values")
        print(" ")
    
    if treat_neg_values == True:
        print("You have opted to correct that by rescaling all your features to a range of 0 to 1")
        print(" ")
        print("We are rescaling you dataframe....")
        scaler = MinMaxScaler(inputCol="features", outputCol="scaledFeatures")

        # Compute summary statistics and generate MinMaxScalerModel
        scalerModel = scaler.fit(output)

        # rescale each feature to range [min, max].
        scaled_data = scalerModel.transform(output)
        final_data = scaled_data.select('label','scaledFeatures') # added class to the selection
        final_data = final_data.withColumnRenamed('scaledFeatures','features')
        print("Done!")

    else:
        print("You have opted not to correct that therefore you will not be able to use to Naive Bayes classifier")
        print("We will return the dataframe unscaled.")
        final_data = output
    
    return final_data

# %%
def ClassTrainEval(classifier,features,classes,folds,train,test):
    
    def FindMtype(classifier):
        # Intstantiate Model
        M = classifier
        # Learn what it is
        Mtype = type(M).__name__
        
        return Mtype
    
    Mtype = FindMtype(classifier)
    

    def IntanceFitModel(Mtype,classifier,classes,features,folds,train):
        
        if Mtype == "OneVsRest":
            # instantiate the base classifier.
            lr = LogisticRegression()
            # instantiate the One Vs Rest Classifier.
            OVRclassifier = OneVsRest(classifier=lr)
#             fitModel = OVRclassifier.fit(train)
            # Add parameters of your choice here:
            paramGrid = ParamGridBuilder() \
                .addGrid(lr.regParam, [0.1, 0.01]) \
                .build()
            #Cross Validator requires the following parameters:
            crossval = CrossValidator(estimator=OVRclassifier,
                                      estimatorParamMaps=paramGrid,
                                      evaluator=MulticlassClassificationEvaluator(),
                                      numFolds=folds) # 3 is best practice
            # Run cross-validation, and choose the best set of parameters.
            fitModel = crossval.fit(train)
            return fitModel
        if Mtype == "MultilayerPerceptronClassifier":
            # specify layers for the neural network:
            # input layer of size features, two intermediate of features+1 and same size as features
            # and output of size number of classes
            # Note: crossvalidator cannot be used here
            features_count = len(features[0][0])
            layers = [features_count, features_count+1, features_count, classes]
            MPC_classifier = MultilayerPerceptronClassifier(maxIter=100, layers=layers, blockSize=128, seed=1234)
            fitModel = MPC_classifier.fit(train)
            return fitModel
        if Mtype in("LinearSVC","GBTClassifier") and classes != 2: # These classifiers currently only accept binary classification
            print(Mtype," could not be used because PySpark currently only accepts binary classification data for this algorithm")
            return
        if Mtype in("LogisticRegression","NaiveBayes","RandomForestClassifier","GBTClassifier","LinearSVC","DecisionTreeClassifier"):
  
            # Add parameters of your choice here:
            if Mtype in("LogisticRegression"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.regParam, [0.1, 0.01]) \
                             .addGrid(classifier.maxIter, [10, 15,20])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("NaiveBayes"):
                paramGrid = (ParamGridBuilder() \
                             .addGrid(classifier.smoothing, [0.0, 0.2, 0.4, 0.6]) \
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("RandomForestClassifier"):
                paramGrid = (ParamGridBuilder() \
                               .addGrid(classifier.maxDepth, [2, 5, 10])
#                                .addGrid(classifier.maxBins, [5, 10, 20])
#                                .addGrid(classifier.numTrees, [5, 20, 50])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("GBTClassifier"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.maxDepth, [2, 5, 10, 20, 30]) \
#                              .addGrid(classifier.maxBins, [10, 20, 40, 80, 100]) \
                             .addGrid(classifier.maxIter, [10, 15,50,100])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("LinearSVC"):
                paramGrid = (ParamGridBuilder() \
                             .addGrid(classifier.maxIter, [10, 15]) \
                             .addGrid(classifier.regParam, [0.1, 0.01]) \
                             .build())
            
            # Add parameters of your choice here:
            if Mtype in("DecisionTreeClassifier"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.maxDepth, [2, 5, 10, 20, 30]) \
                             .addGrid(classifier.maxBins, [10, 20, 40, 80, 100]) \
                             .build())
            
            #Cross Validator requires all of the following parameters:
            crossval = CrossValidator(estimator=classifier,
                                      estimatorParamMaps=paramGrid,
                                      evaluator=MulticlassClassificationEvaluator(),
                                      numFolds=folds) # 3 + is best practice
            # Fit Model: Run cross-validation, and choose the best set of parameters.
            fitModel = crossval.fit(train)
            return fitModel
    
    fitModel = IntanceFitModel(Mtype,classifier,classes,features,folds,train)
    
    # Print feature selection metrics
    if fitModel is not None:
        
        if Mtype in("OneVsRest"):
            # Get Best Model
            BestModel = fitModel.bestModel
            global OVR_BestModel
            OVR_BestModel = BestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            # Extract list of binary models
            models = BestModel.models
            for model in models:
                print('\033[1m' + 'Intercept: '+ '\033[0m',model.intercept)
                print('\033[1m' + 'Top 20 Coefficients:'+ '\033[0m')
                coeff_array = model.coefficients.toArray()
                coeff_scores = []
                for x in coeff_array:
                    coeff_scores.append(float(x))
                # Then zip with input_columns list and create a df
                result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
                print(result.orderBy(result["coeff"].desc()).show(truncate=False))


        if Mtype == "MultilayerPerceptronClassifier":
            print("")
            print('\033[1m' + Mtype + '\033[0m')
            print('\033[1m' + "Model Weights: "+ '\033[0m',fitModel.weights.size)
            print("")
            global MLPC_Model
            MLPC_BestModel = fitModel

        if Mtype in("DecisionTreeClassifier", "GBTClassifier","RandomForestClassifier"):
            # FEATURE IMPORTANCES
            # Estimate of the importance of each feature.
            # Each feature’s importance is the average of its importance across all trees 
            # in the ensemble The importance vector is normalized to sum to 1. 
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype," Top 20 Feature Importances"+ '\033[0m')
            print("(Scores add up to 1)")
            print("Lowest score is the least important")
            print(" ")
            featureImportances = BestModel.featureImportances.toArray()
            # Convert from numpy array to list
            imp_scores = []
            for x in featureImportances:
                imp_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,imp_scores), schema=['feature','score'])
            print(result.orderBy(result["score"].desc()).show(truncate=False))
            
            # Save the feature importance values and the models
            if Mtype in("DecisionTreeClassifier"):
                global DT_featureimportances
                DT_featureimportances = BestModel.featureImportances.toArray()
                global DT_BestModel
                DT_BestModel = BestModel
            if Mtype in("GBTClassifier"):
                global GBT_featureimportances
                GBT_featureimportances = BestModel.featureImportances.toArray()
                global GBT_BestModel
                GBT_BestModel = BestModel
            if Mtype in("RandomForestClassifier"):
                global RF_featureimportances
                RF_featureimportances = BestModel.featureImportances.toArray()
                global RF_BestModel
                RF_BestModel = BestModel

        # Print the coefficients
        if Mtype in("LogisticRegression"):
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            print("Intercept: " + str(BestModel.interceptVector))
            print('\033[1m' + " Top 20 Coefficients"+ '\033[0m')
            print("You should compares these relative to eachother")
            # Convert from numpy array to list
            coeff_array = BestModel.coefficientMatrix.toArray()
            coeff_scores = []
            for x in coeff_array[0]:
                coeff_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
            print(result.orderBy(result["coeff"].desc()).show(truncate=False))
            # Save the coefficient values and the models
            global LR_coefficients
            LR_coefficients = BestModel.coefficientMatrix.toArray()
            global LR_BestModel
            LR_BestModel = BestModel

        # Print the Coefficients
        if Mtype in("LinearSVC"):
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            print("Intercept: " + str(BestModel.intercept))
            print('\033[1m' + "Top 20 Coefficients"+ '\033[0m')
            print("You should compares these relative to eachother")
#             print("Coefficients: \n" + str(BestModel.coefficients))
            coeff_array = BestModel.coefficients.toArray()
            coeff_scores = []
            for x in coeff_array:
                coeff_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
            print(result.orderBy(result["coeff"].desc()).show(truncate=False))
            # Save the coefficient values and the models
            global LSVC_coefficients
            LSVC_coefficients = BestModel.coefficients.toArray()
            global LSVC_BestModel
            LSVC_BestModel = BestModel
        
   
    # Set the column names to match the external results dataframe that we will join with later:
    columns = ['Classifier', 'Result']
    
    if Mtype in("LinearSVC","GBTClassifier") and classes != 2:
        Mtype = [Mtype] # make this a list
        score = ["N/A"]
        result = spark.createDataFrame(zip(Mtype,score), schema=columns)
    else:
        predictions = fitModel.transform(test)
        MC_evaluator = MulticlassClassificationEvaluator(metricName="accuracy") # redictionCol="prediction",
        accuracy = (MC_evaluator.evaluate(predictions))*100
        Mtype = [Mtype] # make this a string
        score = [str(accuracy)] #make this a string and convert to a list
        result = spark.createDataFrame(zip(Mtype,score), schema=columns)
        result = result.withColumn('Result',result.Result.substr(0, 5))
        
    return result
    #Also returns the fit model important scores or p values

# %%
# Set up independ and dependent vars
input_columns = df.columns
input_columns = input_columns[1:-1] # keep only relevant columns: everything but the first and last cols
dependent_var = 'class'

# Learn how many classes there are in order to specify evaluation type based on binary or multi and turn the df into an object
class_count = df.select(countDistinct("class")).collect()
classes = class_count[0][0]

# %%
# Call on data prep, train and evaluate functions
test1_data = MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=False,treat_neg_values=False)
test1_data.limit(5).toPandas()

# Comment out Naive Bayes if your data still contains negative values
classifiers = [
                LogisticRegression()
                ,OneVsRest()
               ,LinearSVC()
#                ,NaiveBayes()
               ,RandomForestClassifier()
               ,GBTClassifier()
               ,DecisionTreeClassifier()
               ,MultilayerPerceptronClassifier()
              ] 

train,test = test1_data.randomSplit([0.7,0.3])
features = test1_data.select(['features']).collect()
folds = 2 # because we have limited data

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
print("!!!!!Final Results!!!!!!!!")
results.show(100,False)
# Out:
# +--------------------+-----+-----+
# |               class|label|count|
# +--------------------+-----+-----+
# |           ReggaeDub| 19.0|  100|
# |           FunkRAndB|  8.0|  100|
# |              Trance| 22.0|  100|
# |              Techno| 21.0|  100|
# |             Dubstep|  5.0|  100|
# |   IndieDanceNuDisco| 15.0|  100|
# |ElectronicaDowntempo|  7.0|  100|
# |               House| 14.0|  100|
# |  HardcoreHardTechno| 12.0|  100|
# |              HipHop| 13.0|  100|
# |           GlitchHop| 10.0|  100|
# |         DrumAndBass|  4.0|  100|
# |           PsyTrance| 18.0|  100|
# |    ProgressiveHouse| 17.0|  100|
# |        ElectroHouse|  6.0|  100|
# |           HardDance| 11.0|  100|
# |             Minimal| 16.0|  100|
# |           TechHouse| 20.0|  100|
# |           DeepHouse|  3.0|  100|
# |             BigRoom|  0.0|  100|
# |         FutureHouse|  9.0|  100|
# |               Dance|  2.0|  100|
# |              Breaks|  1.0|  100|
# +--------------------+-----+-----+
#
# None
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted not to correct that therefore you will not be able to use to Naive Bayes classifier
# We will return the dataframe unscaled.
#
# LogisticRegression
# Intercept: [0.24628790427840874,-35.72076919507738,-55.39058429768146,-19.006992208368743,23.928502778029547,-41.19364441905234,14.367240920695574,28.071996934297925,38.424023743669736,-42.360959008231816,19.149130852496835,-17.087269919150486,47.86369608745201,-41.724997290117884,-3.7709618054216145,4.664869783543939,3.2395333792607732,15.56022833524799,32.88499923111335,14.101874013815927,-18.682343819098666,33.44857500001415,-1.0124370017157953]
#  Top 20 Coefficients
# You should compares these relative to eachother
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |27-ChromaVector6m    |65.73323570494739 |
# |67-ChromaVector12std |52.33508553787158 |
# |33-ChromaVector12m   |50.73401793683302 |
# |63-ChromaVector8std  |43.68561662094587 |
# |22-ChromaVector1m    |43.63900094918618 |
# |64-ChromaVector9std  |25.836609194930915|
# |2-Energym            |21.430491475380254|
# |5-SpectralSpreadm    |19.72538608918823 |
# |52-MFCCs10std        |18.672733193532906|
# |68-ChromaDeviationstd|18.420162758607006|
# |26-ChromaVector5m    |18.271904458508555|
# |30-ChromaVector9m    |15.587760265245883|
# |50-MFCCs8std         |14.985298624386738|
# |58-ChromaVector3std  |13.474461207650624|
# |36-Energystd         |9.968850589414938 |
# |53-MFCCs11std        |6.8562599234458155|
# |3-EnergyEntropym     |5.638325927745845 |
# |24-ChromaVector3m    |5.531401315515722 |
# |49-MFCCs7std         |5.376398464796362 |
# |47-MFCCs5std         |4.927635402370028 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
#
# OneVsRest
# Intercept:  -4.260789564828361
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |63-ChromaVector8std |32.648108330431384|
# |67-ChromaVector12std|29.934722868995497|
# |64-ChromaVector9std |26.701636107752666|
# |22-ChromaVector1m   |18.86879758573102 |
# |27-ChromaVector6m   |13.24614924406016 |
# |5-SpectralSpreadm   |11.61758984035374 |
# |52-MFCCs10std       |8.507036089933806 |
# |30-ChromaVector9m   |8.398137937985927 |
# |58-ChromaVector3std |6.999280691603624 |
# |50-MFCCs8std        |5.568507588491806 |
# |26-ChromaVector5m   |5.432963898698944 |
# |53-MFCCs11std       |5.0120443618972015|
# |2-Energym           |4.815092387803401 |
# |36-Energystd        |2.8780151265174854|
# |3-EnergyEntropym    |2.8470345236007573|
# |62-ChromaVector7std |2.353828597462596 |
# |24-ChromaVector3m   |2.1751135549299683|
# |54-MFCCs12std       |2.0695709351127047|
# |49-MFCCs7std        |1.3450606494552415|
# |18-MFCCs10m         |1.2874667238188793|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -19.73973437231889
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |72.65273610555819 |
# |65-ChromaVector10std  |46.54465201016936 |
# |68-ChromaDeviationstd |33.7487585946825  |
# |61-ChromaVector6std   |25.28201363567158 |
# |34-ChromaDeviationm   |20.29238699578135 |
# |64-ChromaVector9std   |16.446229687282088|
# |22-ChromaVector1m     |8.19979844886107  |
# |66-ChromaVector11std  |5.806176397592813 |
# |62-ChromaVector7std   |5.668194111914722 |
# |52-MFCCs10std         |5.194197582703244 |
# |5-SpectralSpreadm     |4.534749191495872 |
# |28-ChromaVector7m     |4.328839325212735 |
# |42-SpectralRolloffstd |4.171790000245844 |
# |49-MFCCs7std          |3.951578623811293 |
# |24-ChromaVector3m     |3.774265067068189 |
# |54-MFCCs12std         |2.8370536123094063|
# |40-SpectralEntropystd |2.7669082843287627|
# |38-SpectralCentroidstd|2.591975966029958 |
# |3-EnergyEntropym      |2.4778846675517494|
# |44-MFCCs2std          |2.2823472570770087|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -27.700118107172663
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |67-ChromaVector12std  |58.86964240662017 |
# |63-ChromaVector8std   |55.82938026522443 |
# |57-ChromaVector2std   |49.621686586396685|
# |64-ChromaVector9std   |46.79602154159601 |
# |25-ChromaVector4m     |28.70454564522277 |
# |29-ChromaVector8m     |18.469242309384814|
# |39-SpectralSpreadstd  |16.531881135041214|
# |26-ChromaVector5m     |15.393864493463168|
# |31-ChromaVector10m    |15.115274362626733|
# |36-Energystd          |12.943588014561849|
# |38-SpectralCentroidstd|8.08159804624404  |
# |52-MFCCs10std         |7.817290818413844 |
# |22-ChromaVector1m     |7.80272942800168  |
# |3-EnergyEntropym      |6.96512546696669  |
# |5-SpectralSpreadm     |6.757131015559939 |
# |51-MFCCs9std          |5.244437185598073 |
# |50-MFCCs8std          |4.875709442556705 |
# |55-MFCCs13std         |4.611220971916845 |
# |35-ZCRstd             |3.45075881513157  |
# |53-MFCCs11std         |3.3232200701661316|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -15.439808755430922
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |126.64838658333399|
# |33-ChromaVector12m    |77.62413730327796 |
# |67-ChromaVector12std  |59.462835127274154|
# |27-ChromaVector6m     |33.56288779086182 |
# |30-ChromaVector9m     |24.081772508089795|
# |65-ChromaVector10std  |21.154730110050632|
# |38-SpectralCentroidstd|17.77576910967589 |
# |26-ChromaVector5m     |16.790373577887273|
# |57-ChromaVector2std   |14.444181422888134|
# |36-Energystd          |14.00488651306564 |
# |22-ChromaVector1m     |13.187790739291492|
# |55-MFCCs13std         |8.62091865720811  |
# |34-ChromaDeviationm   |8.467876707619586 |
# |58-ChromaVector3std   |8.00325955619652  |
# |70-BPMconf            |7.6431171555825275|
# |32-ChromaVector11m    |7.010043286083652 |
# |5-SpectralSpreadm     |6.458562030840361 |
# |63-ChromaVector8std   |5.5803269457452025|
# |31-ChromaVector10m    |4.909941638599142 |
# |50-MFCCs8std          |4.146526328247786 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  7.133935030875907
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |59-ChromaVector4std  |47.95485915538054 |
# |5-SpectralSpreadm    |28.239201611457336|
# |60-ChromaVector5std  |19.523479319676486|
# |2-Energym            |15.635551327623803|
# |26-ChromaVector5m    |14.252788542222861|
# |23-ChromaVector2m    |12.573022897141406|
# |67-ChromaVector12std |11.103757137260722|
# |22-ChromaVector1m    |10.709346829786611|
# |65-ChromaVector10std |10.103357489767431|
# |34-ChromaDeviationm  |9.747892640601668 |
# |64-ChromaVector9std  |9.28503819245004  |
# |63-ChromaVector8std  |8.650134077221061 |
# |4-SpectralCentroidm  |7.179647734396611 |
# |42-SpectralRolloffstd|7.15910834932258  |
# |33-ChromaVector12m   |4.823698952219189 |
# |30-ChromaVector9m    |3.6607841656199107|
# |55-MFCCs13std        |3.1481373161773516|
# |24-ChromaVector3m    |3.1436826033837657|
# |20-MFCCs12m          |2.160965716994664 |
# |66-ChromaVector11std |1.8271464830110917|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -21.06510178251957
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |65-ChromaVector10std |34.647110560064256|
# |68-ChromaDeviationstd|32.82582395325892 |
# |34-ChromaDeviationm  |31.55357634624832 |
# |33-ChromaVector12m   |26.41764535271755 |
# |25-ChromaVector4m    |23.154334695825334|
# |29-ChromaVector8m    |21.556562317510615|
# |59-ChromaVector4std  |20.420843052984882|
# |67-ChromaVector12std |17.646238637733436|
# |26-ChromaVector5m    |11.83492616446538 |
# |27-ChromaVector6m    |10.241971045956152|
# |36-Energystd         |8.95225190216495  |
# |24-ChromaVector3m    |7.394787005334344 |
# |53-MFCCs11std        |5.684586333861787 |
# |56-ChromaVector1std  |4.587989744810132 |
# |4-SpectralCentroidm  |4.255437730686536 |
# |8-SpectralRolloffm   |3.96928527476933  |
# |50-MFCCs8std         |3.852267559473424 |
# |47-MFCCs5std         |3.794082805780173 |
# |3-EnergyEntropym     |3.337335012223176 |
# |31-ChromaVector10m   |3.2677294379355115|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  4.506689810396409
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |57-ChromaVector2std  |68.45204588829282 |
# |30-ChromaVector9m    |31.220400976927284|
# |22-ChromaVector1m    |23.530220496056366|
# |31-ChromaVector10m   |21.43810288147789 |
# |64-ChromaVector9std  |13.262488616033771|
# |68-ChromaDeviationstd|9.02229759345662  |
# |29-ChromaVector8m    |8.27309088963872  |
# |2-Energym            |5.660222330375866 |
# |23-ChromaVector2m    |4.611541992531083 |
# |51-MFCCs9std         |4.483494904285984 |
# |62-ChromaVector7std  |3.0430962315933963|
# |58-ChromaVector3std  |2.869620194362017 |
# |46-MFCCs4std         |2.4650416180514774|
# |32-ChromaVector11m   |2.1535606022645215|
# |5-SpectralSpreadm    |1.924980494816761 |
# |3-EnergyEntropym     |1.9075340491747212|
# |37-EnergyEntropystd  |1.8743056798308302|
# |25-ChromaVector4m    |1.549242883237521 |
# |45-MFCCs3std         |1.3789221070383135|
# |16-MFCCs8m           |1.3415879055117688|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  11.256271221010945
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |33-ChromaVector12m   |57.99192951686465 |
# |23-ChromaVector2m    |37.9132572161906  |
# |68-ChromaDeviationstd|29.324464630553457|
# |31-ChromaVector10m   |25.456562800636654|
# |26-ChromaVector5m    |23.203120813902615|
# |25-ChromaVector4m    |19.79960392574714 |
# |39-SpectralSpreadstd |16.16772390744273 |
# |41-SpectralFluxstd   |11.155809137638304|
# |32-ChromaVector11m   |10.248315175374607|
# |62-ChromaVector7std  |8.665864329775761 |
# |61-ChromaVector6std  |7.837579412695379 |
# |34-ChromaDeviationm  |5.259995432719466 |
# |36-Energystd         |4.941551137695492 |
# |53-MFCCs11std        |3.0434141323374075|
# |65-ChromaVector10std |3.0306280506409444|
# |30-ChromaVector9m    |2.9832175515926855|
# |52-MFCCs10std        |2.494486847959644 |
# |48-MFCCs6std         |2.140221363047311 |
# |55-MFCCs13std        |1.5350673959443641|
# |37-EnergyEntropystd  |1.0390234655567465|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  9.593407648762266
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |103.73871312755456|
# |67-ChromaVector12std |70.25418559312493 |
# |64-ChromaVector9std  |59.079700860058736|
# |57-ChromaVector2std  |38.12110288442942 |
# |65-ChromaVector10std |29.469748053881226|
# |68-ChromaDeviationstd|21.422837274502672|
# |26-ChromaVector5m    |20.29074524146932 |
# |22-ChromaVector1m    |19.450973099480038|
# |62-ChromaVector7std  |17.60082191234156 |
# |60-ChromaVector5std  |16.600120652650684|
# |39-SpectralSpreadstd |12.564345137705756|
# |55-MFCCs13std        |10.493140279633673|
# |32-ChromaVector11m   |8.678398226453186 |
# |5-SpectralSpreadm    |8.285531042982978 |
# |36-Energystd         |8.099088910980285 |
# |31-ChromaVector10m   |7.467438881165211 |
# |50-MFCCs8std         |5.223632759140384 |
# |49-MFCCs7std         |4.219157998473214 |
# |58-ChromaVector3std  |3.805427276633315 |
# |54-MFCCs12std        |3.6620291404639476|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -19.298510231665357
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |67-ChromaVector12std  |57.78335771251741 |
# |23-ChromaVector2m     |42.437541151134205|
# |41-SpectralFluxstd    |37.27166450314076 |
# |57-ChromaVector2std   |26.41804797494017 |
# |38-SpectralCentroidstd|16.208067428493365|
# |25-ChromaVector4m     |14.8152304656157  |
# |59-ChromaVector4std   |12.66210368154685 |
# |39-SpectralSpreadstd  |12.591980610926408|
# |60-ChromaVector5std   |12.082904747656308|
# |63-ChromaVector8std   |10.65089560417751 |
# |62-ChromaVector7std   |10.366788882080332|
# |3-EnergyEntropym      |9.090817438824535 |
# |29-ChromaVector8m     |8.80157748609591  |
# |61-ChromaVector6std   |8.131403733311366 |
# |55-MFCCs13std         |7.113782534519742 |
# |58-ChromaVector3std   |6.883951813298914 |
# |2-Energym             |5.581857695677914 |
# |36-Energystd          |5.559146626381855 |
# |54-MFCCs12std         |5.258843424440698 |
# |42-SpectralRolloffstd |4.680971516630046 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  4.794802027596175
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |56-ChromaVector1std   |90.98300071405914 |
# |27-ChromaVector6m     |27.578673074694116|
# |59-ChromaVector4std   |19.94432513819679 |
# |65-ChromaVector10std  |18.245896102792337|
# |41-SpectralFluxstd    |12.893722094327464|
# |66-ChromaVector11std  |12.84090056422066 |
# |62-ChromaVector7std   |12.079144643689858|
# |35-ZCRstd             |11.481934032317492|
# |39-SpectralSpreadstd  |8.940604982961906 |
# |58-ChromaVector3std   |7.970538952474164 |
# |67-ChromaVector12std  |6.944168760564189 |
# |52-MFCCs10std         |6.621752934061443 |
# |50-MFCCs8std          |5.6540786240706105|
# |26-ChromaVector5m     |5.530621014258178 |
# |32-ChromaVector11m    |5.405856999015903 |
# |38-SpectralCentroidstd|4.955795658322506 |
# |49-MFCCs7std          |3.760811683616518 |
# |48-MFCCs6std          |3.413181452592695 |
# |53-MFCCs11std         |3.2720377262845246|
# |18-MFCCs10m           |2.2650817222846924|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -13.162270980169474
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |105.87077406212198|
# |67-ChromaVector12std |72.02818531450427 |
# |68-ChromaDeviationstd|38.45951737700527 |
# |61-ChromaVector6std  |19.4130258552727  |
# |70-BPMconf           |18.466057570180062|
# |25-ChromaVector4m    |16.202854609928313|
# |59-ChromaVector4std  |12.985908501891585|
# |64-ChromaVector9std  |11.808481656417186|
# |2-Energym            |7.64283470161435  |
# |48-MFCCs6std         |5.944008816809566 |
# |5-SpectralSpreadm    |5.732296887977441 |
# |26-ChromaVector5m    |5.175393729375295 |
# |58-ChromaVector3std  |3.677621444061464 |
# |46-MFCCs4std         |3.313270431294592 |
# |49-MFCCs7std         |3.2866761959421873|
# |31-ChromaVector10m   |3.2622668845648763|
# |28-ChromaVector7m    |3.108228357332801 |
# |3-EnergyEntropym     |2.856375974966494 |
# |1-ZCRm               |2.811615660361195 |
# |53-MFCCs11std        |2.4633242776683595|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  25.289104383242936
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |30-ChromaVector9m     |52.794406502316136|
# |29-ChromaVector8m     |44.73242153352795 |
# |7-SpectralFluxm       |31.592907225610286|
# |33-ChromaVector12m    |19.3829757806192  |
# |38-SpectralCentroidstd|12.419059503042796|
# |2-Energym             |11.948019362085814|
# |70-BPMconf            |8.926006504761661 |
# |1-ZCRm                |8.282428082169066 |
# |67-ChromaVector12std  |7.931185898351567 |
# |28-ChromaVector7m     |4.031075744390088 |
# |66-ChromaVector11std  |3.579143581569722 |
# |62-ChromaVector7std   |3.1670282323021244|
# |45-MFCCs3std          |2.9805775265892946|
# |13-MFCCs5m            |2.3717816574594472|
# |21-MFCCs13m           |2.0223038674415634|
# |4-SpectralCentroidm   |1.6133487808213027|
# |44-MFCCs2std          |1.0076828648114238|
# |35-ZCRstd             |0.6986634838747856|
# |11-MFCCs3m            |0.6659322404265177|
# |8-SpectralRolloffm    |0.6510502694512491|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -17.506332325510034
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |27-ChromaVector6m   |85.59855246988776 |
# |63-ChromaVector8std |81.37789632680416 |
# |36-Energystd        |17.978688369613106|
# |55-MFCCs13std       |14.64493066934984 |
# |30-ChromaVector9m   |14.399345057311578|
# |34-ChromaDeviationm |12.119874068737984|
# |54-MFCCs12std       |8.151565653109316 |
# |58-ChromaVector3std |6.521671311941728 |
# |60-ChromaVector5std |5.408084598480584 |
# |48-MFCCs6std        |4.773425256499594 |
# |26-ChromaVector5m   |4.002547465379139 |
# |3-EnergyEntropym    |3.839929655196581 |
# |24-ChromaVector3m   |3.6103412287313468|
# |52-MFCCs10std       |3.3794388935511486|
# |23-ChromaVector2m   |3.353371748663237 |
# |44-MFCCs2std        |3.2146290572832354|
# |18-MFCCs10m         |2.9556027440332517|
# |53-MFCCs11std       |2.3823466216036664|
# |66-ChromaVector11std|2.032035010818985 |
# |47-MFCCs5std        |2.007284988962482 |
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.145936510441565
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |107.54245297731522|
# |64-ChromaVector9std   |66.44068430297875 |
# |63-ChromaVector8std   |37.030290122304386|
# |25-ChromaVector4m     |26.756470532068867|
# |38-SpectralCentroidstd|15.738878357949257|
# |35-ZCRstd             |13.08186437973912 |
# |46-MFCCs4std          |5.826959608341362 |
# |62-ChromaVector7std   |5.076550419140241 |
# |54-MFCCs12std         |4.888166080821577 |
# |41-SpectralFluxstd    |4.507948393516076 |
# |65-ChromaVector10std  |4.410329554391373 |
# |36-Energystd          |3.9519805392589524|
# |1-ZCRm                |3.4754512183180206|
# |51-MFCCs9std          |3.4641737453570833|
# |59-ChromaVector4std   |3.239423499146566 |
# |30-ChromaVector9m     |3.0381223883255224|
# |53-MFCCs11std         |2.8288557894767177|
# |58-ChromaVector3std   |2.5159418034632703|
# |50-MFCCs8std          |2.273757285376884 |
# |60-ChromaVector5std   |2.267537043666918 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.46962430905317243
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |64-ChromaVector9std  |54.10103917571736 |
# |68-ChromaDeviationstd|49.12794484068493 |
# |30-ChromaVector9m    |45.70246980882847 |
# |60-ChromaVector5std  |43.790045664553055|
# |63-ChromaVector8std  |37.20537452264678 |
# |39-SpectralSpreadstd |27.152827384121004|
# |23-ChromaVector2m    |20.30640276388754 |
# |36-Energystd         |16.20656724259675 |
# |66-ChromaVector11std |10.632798267635502|
# |54-MFCCs12std        |10.158523267656433|
# |5-SpectralSpreadm    |9.631765684745623 |
# |56-ChromaVector1std  |9.046815730306246 |
# |58-ChromaVector3std  |8.62305673762485  |
# |48-MFCCs6std         |6.870706992295603 |
# |37-EnergyEntropystd  |6.576001297044798 |
# |32-ChromaVector11m   |6.398097315997433 |
# |59-ChromaVector4std  |4.66868077478363  |
# |49-MFCCs7std         |3.4653754180069654|
# |22-ChromaVector1m    |3.4533143866595344|
# |70-BPMconf           |2.617783253715983 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  0.41376552737157013
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |122.6835769874753 |
# |33-ChromaVector12m    |80.70065807681921 |
# |41-SpectralFluxstd    |55.1915455554271  |
# |7-SpectralFluxm       |53.590650858437826|
# |23-ChromaVector2m     |37.00643502074613 |
# |39-SpectralSpreadstd  |33.53345827056932 |
# |59-ChromaVector4std   |24.933204701813704|
# |27-ChromaVector6m     |21.24754493351821 |
# |25-ChromaVector4m     |18.486977113544373|
# |38-SpectralCentroidstd|13.707216958080835|
# |56-ChromaVector1std   |11.620414051463586|
# |31-ChromaVector10m    |10.925713794473273|
# |32-ChromaVector11m    |5.333653341177907 |
# |21-MFCCs13m           |5.2239790066776814|
# |34-ChromaDeviationm   |3.8593540331740748|
# |62-ChromaVector7std   |2.5116194835688366|
# |28-ChromaVector7m     |2.50396843812925  |
# |47-MFCCs5std          |2.2809999855051277|
# |42-SpectralRolloffstd |2.0727806721291953|
# |46-MFCCs4std          |1.8879550250088053|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  2.6857912361878036
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |27-ChromaVector6m     |35.79777357595006 |
# |30-ChromaVector9m     |27.92629038494691 |
# |61-ChromaVector6std   |26.749233386406488|
# |63-ChromaVector8std   |24.7099391924541  |
# |22-ChromaVector1m     |24.23761355934412 |
# |39-SpectralSpreadstd  |17.196293503017312|
# |65-ChromaVector10std  |16.792971695452746|
# |38-SpectralCentroidstd|16.564882559698127|
# |41-SpectralFluxstd    |13.385747994109291|
# |26-ChromaVector5m     |13.358048984585183|
# |36-Energystd          |12.34435381016501 |
# |25-ChromaVector4m     |11.120493767523898|
# |32-ChromaVector11m    |10.795673504906404|
# |60-ChromaVector5std   |8.895798488471456 |
# |58-ChromaVector3std   |8.439105791346355 |
# |55-MFCCs13std         |8.303595415774852 |
# |51-MFCCs9std          |4.983648866389293 |
# |42-SpectralRolloffstd |4.906921713578085 |
# |35-ZCRstd             |4.163756974293744 |
# |50-MFCCs8std          |3.6255508022521448|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  17.808717113564796
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |68-ChromaDeviationstd|66.2025024898116  |
# |67-ChromaVector12std |61.65385649123261 |
# |7-SpectralFluxm      |60.46161811379232 |
# |27-ChromaVector6m    |58.76869466520082 |
# |29-ChromaVector8m    |58.35802942461928 |
# |57-ChromaVector2std  |40.584121401704834|
# |31-ChromaVector10m   |34.96936543228406 |
# |41-SpectralFluxstd   |33.90387193388215 |
# |63-ChromaVector8std  |27.03264972532573 |
# |62-ChromaVector7std  |22.616189597224018|
# |66-ChromaVector11std |21.495800041900488|
# |61-ChromaVector6std  |14.2716304135346  |
# |23-ChromaVector2m    |3.555434255239932 |
# |49-MFCCs7std         |3.078158884560206 |
# |36-Energystd         |2.60190908238334  |
# |33-ChromaVector12m   |1.6148750022488902|
# |47-MFCCs5std         |1.3885680816403203|
# |24-ChromaVector3m    |0.7127854101573474|
# |12-MFCCs4m           |0.5977742569452179|
# |17-MFCCs9m           |0.4780866301219794|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.365840362139559
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |70.76079058735492 |
# |59-ChromaVector4std  |59.79980299921418 |
# |27-ChromaVector6m    |58.03198127388419 |
# |39-SpectralSpreadstd |43.292780798197946|
# |68-ChromaDeviationstd|34.365134031385146|
# |66-ChromaVector11std |32.21103000466354 |
# |29-ChromaVector8m    |22.425040104624735|
# |25-ChromaVector4m    |20.46092526620246 |
# |67-ChromaVector12std |16.02286255379934 |
# |34-ChromaDeviationm  |12.861233596640515|
# |65-ChromaVector10std |12.241399869404882|
# |47-MFCCs5std         |10.042088783611756|
# |55-MFCCs13std        |9.581576194267576 |
# |35-ZCRstd            |7.093864327468316 |
# |54-MFCCs12std        |5.472406320183088 |
# |50-MFCCs8std         |4.637576301724432 |
# |53-MFCCs11std        |4.53629075947076  |
# |62-ChromaVector7std  |4.062046039128469 |
# |51-MFCCs9std         |3.471997620375541 |
# |45-MFCCs3std         |3.1398377128182764|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -10.866680166927225
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |25-ChromaVector4m     |45.431827669633414|
# |30-ChromaVector9m     |33.741814163978276|
# |65-ChromaVector10std  |23.976224184551302|
# |56-ChromaVector1std   |19.328438964492783|
# |60-ChromaVector5std   |17.51408627672058 |
# |41-SpectralFluxstd    |17.130929996314055|
# |35-ZCRstd             |16.2171186913069  |
# |67-ChromaVector12std  |11.950675773287596|
# |34-ChromaDeviationm   |9.813255458918839 |
# |38-SpectralCentroidstd|9.783775684884402 |
# |7-SpectralFluxm       |5.813800511906954 |
# |54-MFCCs12std         |4.650612209167708 |
# |42-SpectralRolloffstd |3.774626697081286 |
# |28-ChromaVector7m     |2.8913962811415073|
# |48-MFCCs6std          |2.8586636737695867|
# |37-EnergyEntropystd   |2.084027304946616 |
# |47-MFCCs5std          |1.987059725266953 |
# |3-EnergyEntropym      |1.8016361249213912|
# |15-MFCCs7m            |1.2932807291665234|
# |4-SpectralCentroidm   |1.0371780107055957|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  10.182898781642383
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |22-ChromaVector1m     |53.069491769609336|
# |25-ChromaVector4m     |46.89714685568214 |
# |30-ChromaVector9m     |44.02012354841866 |
# |29-ChromaVector8m     |32.668664149996886|
# |65-ChromaVector10std  |31.31797297722685 |
# |41-SpectralFluxstd    |28.616673086657524|
# |56-ChromaVector1std   |26.809834692832325|
# |23-ChromaVector2m     |15.59257767301562 |
# |61-ChromaVector6std   |14.772674315511313|
# |38-SpectralCentroidstd|11.178568763800895|
# |36-Energystd          |11.120295174779798|
# |55-MFCCs13std         |10.274461152425618|
# |66-ChromaVector11std  |8.392914961859574 |
# |33-ChromaVector12m    |6.783452717212812 |
# |59-ChromaVector4std   |6.331613491482039 |
# |28-ChromaVector7m     |2.943534266878564 |
# |19-MFCCs11m           |2.7836685611712917|
# |7-SpectralFluxm       |2.532314099240266 |
# |44-MFCCs2std          |2.420876952410232 |
# |18-MFCCs10m           |2.066370580626073 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.9425310953643269
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |33-ChromaVector12m   |56.39682964452894 |
# |30-ChromaVector9m    |51.418909500676264|
# |56-ChromaVector1std  |42.784632988344   |
# |23-ChromaVector2m    |42.59981019552305 |
# |25-ChromaVector4m    |29.07901931639725 |
# |60-ChromaVector5std  |27.45337253742342 |
# |31-ChromaVector10m   |24.50691800028242 |
# |41-SpectralFluxstd   |24.011598582659413|
# |66-ChromaVector11std |21.73834121771046 |
# |7-SpectralFluxm      |21.655308243950085|
# |65-ChromaVector10std |19.337839473586104|
# |5-SpectralSpreadm    |17.377452019252754|
# |62-ChromaVector7std  |13.683925759944868|
# |59-ChromaVector4std  |13.123048341694904|
# |68-ChromaDeviationstd|11.673549552191655|
# |22-ChromaVector1m    |4.701949091788611 |
# |4-SpectralCentroidm  |3.800924580498272 |
# |3-EnergyEntropym     |2.9496151034833638|
# |57-ChromaVector2std  |2.891329765796965 |
# |19-MFCCs11m          |2.699845142858418 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# LinearSVC  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# RandomForestClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +----------------------+--------------------+
# |feature               |score               |
# +----------------------+--------------------+
# |71-BPMessentia        |0.07461410919779861 |
# |69-BPM                |0.05330657505905084 |
# |70-BPMconf            |0.028488404290873938|
# |2-Energym             |0.023828122953700626|
# |3-EnergyEntropym      |0.02225205893126218 |
# |39-SpectralSpreadstd  |0.02138492148772953 |
# |1-ZCRm                |0.02105875938190792 |
# |44-MFCCs2std          |0.020878881076884726|
# |10-MFCCs2m            |0.01867822562434626 |
# |48-MFCCs6std          |0.018517184750649594|
# |50-MFCCs8std          |0.018143048701025923|
# |41-SpectralFluxstd    |0.018072427331508295|
# |4-SpectralCentroidm   |0.017890332687134945|
# |54-MFCCs12std         |0.017767938693371347|
# |53-MFCCs11std         |0.01746498482383466 |
# |9-MFCCs1m             |0.016627020412934256|
# |43-MFCCs1std          |0.01648164605396985 |
# |38-SpectralCentroidstd|0.0164084135693879  |
# |7-SpectralFluxm       |0.01468299322486793 |
# |52-MFCCs10std         |0.014387680120128655|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# GBTClassifier  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# DecisionTreeClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +--------------------+--------------------+
# |feature             |score               |
# +--------------------+--------------------+
# |71-BPMessentia      |0.47076189086965153 |
# |7-SpectralFluxm     |0.0874636067511505  |
# |52-MFCCs10std       |0.06623937165891502 |
# |44-MFCCs2std        |0.060650067610853696|
# |6-SpectralEntropym  |0.03838665079008069 |
# |3-EnergyEntropym    |0.03568431412316532 |
# |9-MFCCs1m           |0.034651797159405966|
# |50-MFCCs8std        |0.027863588138565105|
# |4-SpectralCentroidm |0.026622292735726364|
# |43-MFCCs1std        |0.025238802257045438|
# |39-SpectralSpreadstd|0.021684913386897993|
# |34-ChromaDeviationm |0.020715185487763518|
# |37-EnergyEntropystd |0.01848195804039452 |
# |55-MFCCs13std       |0.013108991369291646|
# |24-ChromaVector3m   |0.012533247554594581|
# |49-MFCCs7std        |0.009723365122174251|
# |19-MFCCs11m         |0.007567077349156314|
# |2-Energym           |0.005608539682315859|
# |46-MFCCs4std        |0.004595886684119945|
# |25-ChromaVector4m   |0.004445201874804525|
# +--------------------+--------------------+
# only showing top 20 rows
#
# None
#
# MultilayerPerceptronClassifier
# Model Weights:  12023
#
# !!!!!Final Results!!!!!!!!
# +------------------------------+------+
# |Classifier                    |Result|
# +------------------------------+------+
# |LogisticRegression            |44.68 |
# |OneVsRest                     |44.97 |
# |LinearSVC                     |N/A   |
# |RandomForestClassifier        |42.64 |
# |GBTClassifier                 |N/A   |
# |DecisionTreeClassifier        |37.55 |
# |MultilayerPerceptronClassifier|15.13 |
# +------------------------------+------+

# %%
# Call on data prep, train and evaluate functions
test2_data = MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=True,treat_neg_values=True)
test2_data.limit(5).toPandas()

# Comment out Naive Bayes if your data still contains negative values
classifiers = [
                LogisticRegression()
                ,OneVsRest()
               ,LinearSVC()
               ,NaiveBayes()
               ,RandomForestClassifier()
               ,GBTClassifier()
               ,DecisionTreeClassifier()
               ,MultilayerPerceptronClassifier()
              ] 

train,test = test2_data.randomSplit([0.7,0.3])
features = test2_data.select(['features']).collect()
folds = 2

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
print("!!!!!Final Results!!!!!!!!")
results.show(100,False)
# Out:
# +--------------------+-----+-----+
# |               class|label|count|
# +--------------------+-----+-----+
# |           ReggaeDub| 19.0|  100|
# |           FunkRAndB|  8.0|  100|
# |              Trance| 22.0|  100|
# |              Techno| 21.0|  100|
# |             Dubstep|  5.0|  100|
# |   IndieDanceNuDisco| 15.0|  100|
# |ElectronicaDowntempo|  7.0|  100|
# |               House| 14.0|  100|
# |  HardcoreHardTechno| 12.0|  100|
# |              HipHop| 13.0|  100|
# |           GlitchHop| 10.0|  100|
# |         DrumAndBass|  4.0|  100|
# |           PsyTrance| 18.0|  100|
# |    ProgressiveHouse| 17.0|  100|
# |        ElectroHouse|  6.0|  100|
# |           HardDance| 11.0|  100|
# |             Minimal| 16.0|  100|
# |           TechHouse| 20.0|  100|
# |           DeepHouse|  3.0|  100|
# |             BigRoom|  0.0|  100|
# |         FutureHouse|  9.0|  100|
# |               Dance|  2.0|  100|
# |              Breaks|  1.0|  100|
# +--------------------+-----+-----+
#
# None
# We are correcting for non normality now!
# 7-SpectralFluxm has been treated for positive (right) skewness. (skew =) 1.6396138160129063 )
# 22-ChromaVector1m has been treated for positive (right) skewness. (skew =) 2.4162415204309258 )
# 23-ChromaVector2m has been treated for positive (right) skewness. (skew =) 4.154796693680583 )
# 24-ChromaVector3m has been treated for positive (right) skewness. (skew =) 1.1974019617504328 )
# 25-ChromaVector4m has been treated for positive (right) skewness. (skew =) 2.446635863594906 )
# 26-ChromaVector5m has been treated for positive (right) skewness. (skew =) 2.154482876187508 )
# 27-ChromaVector6m has been treated for positive (right) skewness. (skew =) 2.01234064472543 )
# 28-ChromaVector7m has been treated for positive (right) skewness. (skew =) 1.1829228989215521 )
# 29-ChromaVector8m has been treated for positive (right) skewness. (skew =) 3.7372643733999955 )
# 30-ChromaVector9m has been treated for positive (right) skewness. (skew =) 2.4117416421548645 )
# 31-ChromaVector10m has been treated for positive (right) skewness. (skew =) 2.1979538518563233 )
# 32-ChromaVector11m has been treated for positive (right) skewness. (skew =) 2.1924295373960554 )
# 33-ChromaVector12m has been treated for positive (right) skewness. (skew =) 2.278981912155668 )
# 41-SpectralFluxstd has been treated for positive (right) skewness. (skew =) 1.8577721462401056 )
# 56-ChromaVector1std has been treated for positive (right) skewness. (skew =) 1.9111935514138085 )
# 57-ChromaVector2std has been treated for positive (right) skewness. (skew =) 2.9078740765487394 )
# 59-ChromaVector4std has been treated for positive (right) skewness. (skew =) 2.9677243313898827 )
# 60-ChromaVector5std has been treated for positive (right) skewness. (skew =) 2.3681450229993315 )
# 61-ChromaVector6std has been treated for positive (right) skewness. (skew =) 2.3950817653605396 )
# 63-ChromaVector8std has been treated for positive (right) skewness. (skew =) 2.801578595136121 )
# 64-ChromaVector9std has been treated for positive (right) skewness. (skew =) 1.7779798465610313 )
# 65-ChromaVector10std has been treated for positive (right) skewness. (skew =) 1.9944501757850421 )
# 66-ChromaVector11std has been treated for positive (right) skewness. (skew =) 1.1835182964170816 )
# 67-ChromaVector12std has been treated for positive (right) skewness. (skew =) 2.087086908618814 )
# 69-BPM has been treated for positive (right) skewness. (skew =) 2.9547734198613234 )
# 70-BPMconf has been treated for positive (right) skewness. (skew =) 1.0889332324135428 )
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted to correct that by rescaling all your features to a range of 0 to 1
#
# We are rescaling you dataframe....
# Done!
#
# LogisticRegression
# Intercept: [-4.368485487864183,-0.36351779855917166,-6.857310649610104,5.86360898131188,-2.576952619817521,-6.181542110112983,-0.22728575297456743,14.193398092040448,-6.354139489857732,-3.0324552888407554,-4.009336862966515,-6.315960856814638,16.11671265316719,-2.2256656644839303,-4.171035879682097,-1.6860837829474256,3.417553089668161,4.618352329794126,6.9559918591280505,-3.9228746870977553,3.4745490610189993,-2.3525124592513125,0.004993324751830776]
#  Top 20 Coefficients
# You should compares these relative to eachother
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |9-MFCCs1m           |6.544034272234215 |
# |2-Energym           |4.956931405285941 |
# |24-ChromaVector3m   |2.7468287170476415|
# |36-Energystd        |2.712081741282161 |
# |71-BPMessentia      |2.690849871710963 |
# |53-MFCCs11std       |2.564243530371949 |
# |5-SpectralSpreadm   |2.431683141133667 |
# |33-ChromaVector12m  |2.306449676288025 |
# |63-ChromaVector8std |2.256776634019064 |
# |15-MFCCs7m          |2.0645342505232804|
# |3-EnergyEntropym    |2.0188333665306852|
# |50-MFCCs8std        |1.7907917059521188|
# |67-ChromaVector12std|1.710624104161458 |
# |58-ChromaVector3std |1.6921672651750452|
# |54-MFCCs12std       |1.538839023217302 |
# |52-MFCCs10std       |1.5192448840443327|
# |18-MFCCs10m         |1.4326814318190608|
# |22-ChromaVector1m   |1.2518722762627323|
# |13-MFCCs5m          |1.193516086352827 |
# |6-SpectralEntropym  |1.0537177889354048|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
#
# OneVsRest
# Intercept:  -4.462645134268283
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |9-MFCCs1m           |3.8742234764244534|
# |43-MFCCs1std        |1.8771450230477704|
# |71-BPMessentia      |1.792450850612357 |
# |53-MFCCs11std       |1.7794354366614618|
# |5-SpectralSpreadm   |1.6157799456273054|
# |11-MFCCs3m          |1.5789319760315448|
# |22-ChromaVector1m   |1.486602165028049 |
# |33-ChromaVector12m  |1.4801258834369369|
# |18-MFCCs10m         |1.4483148721683188|
# |63-ChromaVector8std |1.3145287780683221|
# |2-Energym           |1.291897335329771 |
# |36-Energystd        |1.2888202267634445|
# |3-EnergyEntropym    |1.233094710325518 |
# |54-MFCCs12std       |1.1006715586206217|
# |15-MFCCs7m          |1.022542834441299 |
# |24-ChromaVector3m   |0.9748007625049114|
# |67-ChromaVector12std|0.9746613458375191|
# |52-MFCCs10std       |0.8100017972866347|
# |12-MFCCs4m          |0.7384768893067001|
# |50-MFCCs8std        |0.7191153103991497|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.395148659822752
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |71-BPMessentia       |3.914848889904353  |
# |40-SpectralEntropystd|3.153960625801328  |
# |44-MFCCs2std         |2.6692877353865327 |
# |49-MFCCs7std         |2.319124058286154  |
# |28-ChromaVector7m    |1.999651338133991  |
# |5-SpectralSpreadm    |1.9623479663582715 |
# |34-ChromaDeviationm  |1.9506968404074234 |
# |24-ChromaVector3m    |1.7530024025397735 |
# |69-BPM               |1.6869412806296435 |
# |3-EnergyEntropym     |1.3278437973139954 |
# |64-ChromaVector9std  |1.2916162796228963 |
# |42-SpectralRolloffstd|1.2453907662927575 |
# |66-ChromaVector11std |1.194892305175153  |
# |43-MFCCs1std         |0.896430551589832  |
# |54-MFCCs12std        |0.8841611702771888 |
# |61-ChromaVector6std  |0.746291449870279  |
# |16-MFCCs8m           |0.6954948698167862 |
# |65-ChromaVector10std |0.6853921810234967 |
# |57-ChromaVector2std  |0.5120430747905705 |
# |68-ChromaDeviationstd|0.40906637773094007|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.136130605324586
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |12-MFCCs4m            |2.5498787221692014|
# |3-EnergyEntropym      |2.515924687627549 |
# |51-MFCCs9std          |2.1185769425960395|
# |9-MFCCs1m             |1.6050831713913594|
# |67-ChromaVector12std  |1.3079017839023712|
# |55-MFCCs13std         |1.2986279240721854|
# |17-MFCCs9m            |1.2788955477211594|
# |45-MFCCs3std          |1.2674382001253384|
# |39-SpectralSpreadstd  |1.2496607442208345|
# |16-MFCCs8m            |1.2109759645199496|
# |52-MFCCs10std         |1.1920545049323104|
# |29-ChromaVector8m     |1.134940674846498 |
# |25-ChromaVector4m     |1.1266892112369018|
# |40-SpectralEntropystd |1.1085911719601655|
# |58-ChromaVector3std   |1.0809821705809275|
# |36-Energystd          |1.0432245989183413|
# |22-ChromaVector1m     |0.965320773694877 |
# |10-MFCCs2m            |0.8343705752716489|
# |38-SpectralCentroidstd|0.8213810990601076|
# |26-ChromaVector5m     |0.7720293517557768|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.7492418824516776
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |70-BPMconf            |2.6962416853416813|
# |33-ChromaVector12m    |2.581656322464383 |
# |36-Energystd          |2.322746890314752 |
# |29-ChromaVector8m     |2.2108453146337075|
# |38-SpectralCentroidstd|2.207562541263131 |
# |10-MFCCs2m            |2.0850470724278547|
# |23-ChromaVector2m     |1.9212703340266206|
# |67-ChromaVector12std  |1.7691421000857326|
# |55-MFCCs13std         |1.5593698881345828|
# |22-ChromaVector1m     |1.481822488537568 |
# |58-ChromaVector3std   |1.4773570922095804|
# |66-ChromaVector11std  |1.2823118609107678|
# |53-MFCCs11std         |1.2533327871691795|
# |26-ChromaVector5m     |1.241705246595399 |
# |27-ChromaVector6m     |1.141505623616189 |
# |11-MFCCs3m            |1.0901710401993545|
# |71-BPMessentia        |1.0027016073850852|
# |47-MFCCs5std          |0.8784303055437688|
# |64-ChromaVector9std   |0.8008194012211628|
# |68-ChromaDeviationstd |0.7107500648268906|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.203293462689444
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |2-Energym            |4.100802632714083 |
# |5-SpectralSpreadm    |4.025911550170698 |
# |59-ChromaVector4std  |3.025017289674544 |
# |43-MFCCs1std         |2.736684500789476 |
# |69-BPM               |2.723493705988504 |
# |4-SpectralCentroidm  |1.9999969474377954|
# |42-SpectralRolloffstd|1.8509246929053222|
# |11-MFCCs3m           |1.754222191970805 |
# |10-MFCCs2m           |1.7072223996076903|
# |24-ChromaVector3m    |1.6972355929146745|
# |20-MFCCs12m          |1.6721073457551707|
# |40-SpectralEntropystd|1.378976410759481 |
# |44-MFCCs2std         |1.349354795535957 |
# |17-MFCCs9m           |1.2316673490043004|
# |48-MFCCs6std         |1.0885857440110887|
# |34-ChromaDeviationm  |1.0181460700077698|
# |63-ChromaVector8std  |0.9012375896586301|
# |26-ChromaVector5m    |0.8980948991508508|
# |60-ChromaVector5std  |0.8263484122457698|
# |66-ChromaVector11std |0.801250318280151 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.47273554173267
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |69-BPM               |3.4377753492304906|
# |13-MFCCs5m           |3.090255863173069 |
# |24-ChromaVector3m    |3.0400204228919034|
# |34-ChromaDeviationm  |2.3692999657614715|
# |45-MFCCs3std         |2.1934870052517663|
# |8-SpectralRolloffm   |1.8373137234984678|
# |36-Energystd         |1.6201204712392234|
# |3-EnergyEntropym     |1.6187616813415953|
# |65-ChromaVector10std |1.314332557709452 |
# |44-MFCCs2std         |1.2920026951325887|
# |53-MFCCs11std        |1.1435839521054538|
# |47-MFCCs5std         |1.0991529394305237|
# |68-ChromaDeviationstd|1.0490200004480899|
# |26-ChromaVector5m    |1.0064185986315322|
# |4-SpectralCentroidm  |0.8943331728488115|
# |35-ZCRstd            |0.8329915132189678|
# |30-ChromaVector9m    |0.8148684828674311|
# |6-SpectralEntropym   |0.6536128562536765|
# |42-SpectralRolloffstd|0.6425140646563946|
# |50-MFCCs8std         |0.6342172140022938|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.6861940237565585
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |3.9322974803611785|
# |43-MFCCs1std       |3.1783216628925177|
# |71-BPMessentia     |2.7873195819188075|
# |2-Energym          |2.3610983064475106|
# |46-MFCCs4std       |1.9492056371250424|
# |51-MFCCs9std       |1.70981686907655  |
# |12-MFCCs4m         |1.614394645469593 |
# |3-EnergyEntropym   |1.374063881523754 |
# |22-ChromaVector1m  |1.3379703786369528|
# |23-ChromaVector2m  |1.2138801610589345|
# |6-SpectralEntropym |1.0979266921055981|
# |45-MFCCs3std       |1.0537322906396844|
# |11-MFCCs3m         |0.8991465352817818|
# |30-ChromaVector9m  |0.8554386791345029|
# |47-MFCCs5std       |0.7369007414925425|
# |19-MFCCs11m        |0.7214504568860544|
# |62-ChromaVector7std|0.7054521154483384|
# |29-ChromaVector8m  |0.6468315403029935|
# |31-ChromaVector10m |0.6040024274464081|
# |37-EnergyEntropystd|0.5584764726153407|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  4.80056820891754
# Top 20 Coefficients:
# +--------------------+-------------------+
# |feature             |coeff              |
# +--------------------+-------------------+
# |15-MFCCs7m          |1.6753074735864446 |
# |26-ChromaVector5m   |1.590363689504794  |
# |39-SpectralSpreadstd|1.3964646084226795 |
# |18-MFCCs10m         |1.3273440897376774 |
# |69-BPM              |1.28529334779477   |
# |36-Energystd        |1.2180556630281845 |
# |33-ChromaVector12m  |1.1124830378722916 |
# |10-MFCCs2m          |1.1080764373737189 |
# |30-ChromaVector9m   |1.1062218758087208 |
# |32-ChromaVector11m  |1.0693303280120707 |
# |37-EnergyEntropystd |0.9909731866319775 |
# |23-ChromaVector2m   |0.9652913314147655 |
# |61-ChromaVector6std |0.8110923407892866 |
# |53-MFCCs11std       |0.7006954565398457 |
# |48-MFCCs6std        |0.6927214533304661 |
# |46-MFCCs4std        |0.6723806303213385 |
# |5-SpectralSpreadm   |0.5929392711527989 |
# |62-ChromaVector7std |0.5528860912567791 |
# |54-MFCCs12std       |0.46774527096242335|
# |41-SpectralFluxstd  |0.4230057495953335 |
# +--------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.485415004276327
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |11-MFCCs3m           |2.8531280662673084|
# |63-ChromaVector8std  |2.267351469984135 |
# |62-ChromaVector7std  |2.214924409421011 |
# |64-ChromaVector9std  |2.037585462190152 |
# |9-MFCCs1m            |1.905671591201338 |
# |50-MFCCs8std         |1.8682632549970095|
# |68-ChromaDeviationstd|1.8532726621049127|
# |17-MFCCs9m           |1.7696571989651715|
# |48-MFCCs6std         |1.6948047184774229|
# |49-MFCCs7std         |1.6838961118775109|
# |55-MFCCs13std        |1.6777924190169047|
# |32-ChromaVector11m   |1.6668099224353947|
# |57-ChromaVector2std  |1.6397716339482862|
# |40-SpectralEntropystd|1.5889495874464856|
# |67-ChromaVector12std |1.4785510568884277|
# |60-ChromaVector5std  |1.424304655228379 |
# |36-Energystd         |1.413668807888955 |
# |19-MFCCs11m          |1.3647720214755694|
# |58-ChromaVector3std  |1.3363951722961005|
# |12-MFCCs4m           |1.2066987958378141|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.435450933633505
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |4.110889569133172 |
# |9-MFCCs1m             |4.071788209584205 |
# |43-MFCCs1std          |2.208370884246714 |
# |71-BPMessentia        |2.191368326653966 |
# |60-ChromaVector5std   |2.1188259966377254|
# |17-MFCCs9m            |1.553096115502068 |
# |67-ChromaVector12std  |1.279231173409249 |
# |36-Energystd          |1.263045167383785 |
# |40-SpectralEntropystd |1.254448519207933 |
# |38-SpectralCentroidstd|1.1945956095841628|
# |62-ChromaVector7std   |1.1139143045008264|
# |53-MFCCs11std         |1.087047493099035 |
# |58-ChromaVector3std   |1.0816654463469058|
# |42-SpectralRolloffstd |1.0292239968347086|
# |55-MFCCs13std         |0.9506392272879548|
# |44-MFCCs2std          |0.9027112915622252|
# |63-ChromaVector8std   |0.7767911715851129|
# |61-ChromaVector6std   |0.7669997103618202|
# |54-MFCCs12std         |0.6866813229227553|
# |2-Energym             |0.6785159563798089|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.642127302867381
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |56-ChromaVector1std|5.473096843138758 |
# |18-MFCCs10m        |2.8550797106348953|
# |9-MFCCs1m          |2.2411129110129697|
# |45-MFCCs3std       |1.8521900478245859|
# |69-BPM             |1.7218569767605563|
# |62-ChromaVector7std|1.5792705041405004|
# |41-SpectralFluxstd |1.5139519050765735|
# |50-MFCCs8std       |1.3401670770717806|
# |27-ChromaVector6m  |1.1677593976238057|
# |26-ChromaVector5m  |1.1475117673878865|
# |21-MFCCs13m        |1.129890242410386 |
# |48-MFCCs6std       |1.0283277162068234|
# |58-ChromaVector3std|0.882300726266108 |
# |59-ChromaVector4std|0.8509537890300953|
# |32-ChromaVector11m |0.847235549519195 |
# |35-ZCRstd          |0.7391393796640371|
# |52-MFCCs10std      |0.7086141698659284|
# |11-MFCCs3m         |0.699535656537968 |
# |15-MFCCs7m         |0.6543195405201998|
# |43-MFCCs1std       |0.5978005489213335|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.613427236624881
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.083011397100815 |
# |2-Energym            |2.768538130622402 |
# |63-ChromaVector8std  |2.4457979839800625|
# |67-ChromaVector12std |2.2929391353156783|
# |69-BPM               |2.0661587373836303|
# |48-MFCCs6std         |1.568700415911433 |
# |13-MFCCs5m           |1.538645315663955 |
# |52-MFCCs10std        |1.4687791194761275|
# |5-SpectralSpreadm    |1.403153179047201 |
# |71-BPMessentia       |1.393204156973851 |
# |9-MFCCs1m            |1.3908360148682648|
# |3-EnergyEntropym     |1.3754441558742398|
# |59-ChromaVector4std  |1.173373147466203 |
# |28-ChromaVector7m    |1.1584099921336426|
# |14-MFCCs6m           |1.116439958404806 |
# |16-MFCCs8m           |1.1071618896830557|
# |61-ChromaVector6std  |1.0878428573352226|
# |46-MFCCs4std         |0.9490549782252797|
# |68-ChromaDeviationstd|0.8731555826590988|
# |25-ChromaVector4m    |0.8132625198733868|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  7.992232189480349
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |2-Energym             |3.030659502182852  |
# |70-BPMconf            |2.717237822872579  |
# |1-ZCRm                |2.3112224464265347 |
# |13-MFCCs5m            |2.145741912338247  |
# |7-SpectralFluxm       |2.0765966290135496 |
# |45-MFCCs3std          |1.661132042947048  |
# |15-MFCCs7m            |1.638590125970389  |
# |30-ChromaVector9m     |1.4740118724329117 |
# |28-ChromaVector7m     |1.2440063280814253 |
# |38-SpectralCentroidstd|1.1151312719854327 |
# |44-MFCCs2std          |1.0832016910614728 |
# |71-BPMessentia        |0.9000476810929763 |
# |66-ChromaVector11std  |0.7543270603102835 |
# |4-SpectralCentroidm   |0.7134382090771328 |
# |8-SpectralRolloffm    |0.5429019025409701 |
# |21-MFCCs13m           |0.5299123661271936 |
# |62-ChromaVector7std   |0.5222996810413192 |
# |29-ChromaVector8m     |0.18694399815923887|
# |12-MFCCs4m            |0.16344418893937057|
# |33-ChromaVector12m    |0.15850467774643556|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.520940960203317
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |69-BPM             |3.5992690241978944|
# |44-MFCCs2std       |3.297805632508104 |
# |18-MFCCs10m        |3.15146066656375  |
# |27-ChromaVector6m  |2.996673957667906 |
# |55-MFCCs13std      |2.9750833278086564|
# |36-Energystd       |2.6595646293586643|
# |63-ChromaVector8std|2.125292006627292 |
# |46-MFCCs4std       |1.939540893643796 |
# |3-EnergyEntropym   |1.8298392584325904|
# |48-MFCCs6std       |1.4233060985961403|
# |29-ChromaVector8m  |1.280860096624649 |
# |34-ChromaDeviationm|1.2138714657833072|
# |54-MFCCs12std      |1.200738583862119 |
# |24-ChromaVector3m  |1.181508097855093 |
# |52-MFCCs10std      |1.1229688884686528|
# |2-Energym          |1.1081836708684842|
# |6-SpectralEntropym |0.8958338970620118|
# |30-ChromaVector9m  |0.8138875833983329|
# |14-MFCCs6m         |0.7335855026174782|
# |60-ChromaVector5std|0.6352041817423183|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.8340817248005106
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |2.877814740298715 |
# |71-BPMessentia        |2.0465214418213398|
# |11-MFCCs3m            |1.995489175254738 |
# |43-MFCCs1std          |1.855368052628222 |
# |64-ChromaVector9std   |1.7704034671350772|
# |38-SpectralCentroidstd|1.7028750105642532|
# |60-ChromaVector5std   |1.5061762924284559|
# |46-MFCCs4std          |1.4571853557270062|
# |35-ZCRstd             |1.4269792098287242|
# |17-MFCCs9m            |1.3136140856471177|
# |36-Energystd          |1.3121494771378353|
# |63-ChromaVector8std   |1.2081111377673053|
# |40-SpectralEntropystd |1.1561191955878662|
# |54-MFCCs12std         |1.134543403635206 |
# |3-EnergyEntropym      |0.9891805589578936|
# |42-SpectralRolloffstd |0.9604629663674609|
# |44-MFCCs2std          |0.8505017389820245|
# |53-MFCCs11std         |0.7988565204842659|
# |55-MFCCs13std         |0.6557138079193442|
# |66-ChromaVector11std  |0.6169714653665053|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.652324629801914
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |60-ChromaVector5std  |2.5160178553757184|
# |68-ChromaDeviationstd|2.4518657523355682|
# |39-SpectralSpreadstd |2.4187190520664115|
# |11-MFCCs3m           |2.4035586652258316|
# |36-Energystd         |2.290902360159192 |
# |32-ChromaVector11m   |2.2487033005621373|
# |29-ChromaVector8m    |1.8913610315400085|
# |37-EnergyEntropystd  |1.6459064344350265|
# |16-MFCCs8m           |1.53657968137553  |
# |19-MFCCs11m          |1.4969284379358871|
# |49-MFCCs7std         |1.3997606454383216|
# |45-MFCCs3std         |1.3678855253589033|
# |20-MFCCs12m          |1.355459366157961 |
# |5-SpectralSpreadm    |1.2203769244945244|
# |58-ChromaVector3std  |1.1733205207885111|
# |10-MFCCs2m           |0.9781493234752073|
# |18-MFCCs10m          |0.9751435884739272|
# |30-ChromaVector9m    |0.9696560407377786|
# |63-ChromaVector8std  |0.9525749920555211|
# |40-SpectralEntropystd|0.9324877232965277|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.87852095713192
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |43-MFCCs1std          |3.550649613758992 |
# |41-SpectralFluxstd    |3.4518309375370952|
# |7-SpectralFluxm       |2.6554785621709716|
# |71-BPMessentia        |2.349449960759408 |
# |39-SpectralSpreadstd  |2.1940403430424413|
# |21-MFCCs13m           |1.9758805251204454|
# |38-SpectralCentroidstd|1.7913364136109093|
# |25-ChromaVector4m     |1.7848990316200237|
# |27-ChromaVector6m     |1.6165928742041402|
# |32-ChromaVector11m    |1.4992778038469396|
# |20-MFCCs12m           |1.4905914000692935|
# |29-ChromaVector8m     |1.2148801615533298|
# |45-MFCCs3std          |1.1439084273016245|
# |17-MFCCs9m            |1.118687797336188 |
# |14-MFCCs6m            |1.0986203341497491|
# |13-MFCCs5m            |1.0653306128207927|
# |22-ChromaVector1m     |0.8166617208179406|
# |37-EnergyEntropystd   |0.796641787814217 |
# |30-ChromaVector9m     |0.7957394206191073|
# |47-MFCCs5std          |0.7941351955824227|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.571183443257012
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |10-MFCCs2m            |2.8316170112538677|
# |32-ChromaVector11m    |2.394306570153558 |
# |17-MFCCs9m            |2.058127814558033 |
# |29-ChromaVector8m     |2.0555988765192303|
# |38-SpectralCentroidstd|1.8274044665984004|
# |70-BPMconf            |1.7072233852293035|
# |65-ChromaVector10std  |1.4650735503566172|
# |20-MFCCs12m           |1.351029393238775 |
# |36-Energystd          |1.3131389330964827|
# |21-MFCCs13m           |1.30412803218999  |
# |51-MFCCs9std          |1.2555009388909446|
# |54-MFCCs12std         |1.1997851906570067|
# |57-ChromaVector2std   |1.1803851848471518|
# |24-ChromaVector3m     |1.073344455103942 |
# |42-SpectralRolloffstd |0.9050727253772151|
# |40-SpectralEntropystd |0.8940472372254242|
# |26-ChromaVector5m     |0.8386755618239872|
# |27-ChromaVector6m     |0.8246846745746864|
# |58-ChromaVector3std   |0.8074328048272779|
# |41-SpectralFluxstd    |0.7527341913646483|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  2.8230155861770996
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |71-BPMessentia       |6.8113993890453575 |
# |29-ChromaVector8m    |3.381511903842609  |
# |7-SpectralFluxm      |3.3040495578972386 |
# |41-SpectralFluxstd   |2.624292017448517  |
# |9-MFCCs1m            |2.6014768291309704 |
# |62-ChromaVector7std  |2.4122177573962977 |
# |69-BPM               |2.0964492609274616 |
# |68-ChromaDeviationstd|1.9063378880029593 |
# |66-ChromaVector11std |1.5109225868800198 |
# |67-ChromaVector12std |1.4613358622423478 |
# |17-MFCCs9m           |1.3520756962691138 |
# |63-ChromaVector8std  |1.2449146167399645 |
# |31-ChromaVector10m   |1.2056660071206584 |
# |49-MFCCs7std         |1.057537955202026  |
# |57-ChromaVector2std  |1.0477068548000417 |
# |27-ChromaVector6m    |0.9750902646939776 |
# |36-Energystd         |0.7776249341619316 |
# |12-MFCCs4m           |0.5767177380881893 |
# |26-ChromaVector5m    |0.5543195432580731 |
# |24-ChromaVector3m    |0.48938982534183667|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.781291513842784
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |59-ChromaVector4std  |3.5026991871168875|
# |47-MFCCs5std         |3.252097440536721 |
# |39-SpectralSpreadstd |2.5885122445018833|
# |66-ChromaVector11std |2.4952024088096314|
# |54-MFCCs12std        |2.302452482915721 |
# |55-MFCCs13std        |2.1345601379830668|
# |63-ChromaVector8std  |2.066434515297856 |
# |45-MFCCs3std         |1.8287817607940067|
# |27-ChromaVector6m    |1.7744295024323518|
# |37-EnergyEntropystd  |1.7020116245096966|
# |15-MFCCs7m           |1.6573914256853783|
# |35-ZCRstd            |1.4637837382640204|
# |20-MFCCs12m          |1.4518834429113325|
# |51-MFCCs9std         |1.4420917061237626|
# |69-BPM               |1.3202778503042012|
# |34-ChromaDeviationm  |1.284047177714124 |
# |12-MFCCs4m           |1.2807797544205095|
# |68-ChromaDeviationstd|1.2663490153828694|
# |25-ChromaVector4m    |1.1291111653175359|
# |67-ChromaVector12std |1.070151464803878 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.062609488904039
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |11-MFCCs3m            |2.7663080983366344|
# |56-ChromaVector1std   |2.3095903520826453|
# |38-SpectralCentroidstd|1.9318763656238167|
# |41-SpectralFluxstd    |1.8746428134279531|
# |25-ChromaVector4m     |1.8165388174753707|
# |43-MFCCs1std          |1.6961048673969843|
# |35-ZCRstd             |1.6881385719416244|
# |71-BPMessentia        |1.345289716690109 |
# |37-EnergyEntropystd   |1.2113664254043002|
# |65-ChromaVector10std  |1.1350413363379153|
# |42-SpectralRolloffstd |1.0496240620837713|
# |13-MFCCs5m            |1.040384867511007 |
# |47-MFCCs5std          |0.9765372661729402|
# |54-MFCCs12std         |0.9053290129777357|
# |3-EnergyEntropym      |0.8522016628754756|
# |67-ChromaVector12std  |0.8165225875698406|
# |45-MFCCs3std          |0.7620183551533195|
# |12-MFCCs4m            |0.7282135024056205|
# |4-SpectralCentroidm   |0.7279365091655178|
# |70-BPMconf            |0.6882499704972345|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.214189438906168
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |18-MFCCs10m           |3.735141777625355 |
# |65-ChromaVector10std  |2.8107827713393356|
# |36-Energystd          |2.574090614772706 |
# |19-MFCCs11m           |2.2790597994798736|
# |44-MFCCs2std          |2.066316431934452 |
# |15-MFCCs7m            |1.8106011634890886|
# |9-MFCCs1m             |1.7364176963345006|
# |12-MFCCs4m            |1.7112000593275227|
# |41-SpectralFluxstd    |1.6638769610812019|
# |56-ChromaVector1std   |1.4617203193732964|
# |10-MFCCs2m            |1.319437586498865 |
# |42-SpectralRolloffstd |1.3168809999488504|
# |55-MFCCs13std         |1.3032336549502554|
# |38-SpectralCentroidstd|1.2823454315268537|
# |28-ChromaVector7m     |1.236948017190826 |
# |22-ChromaVector1m     |1.1309147550208025|
# |71-BPMessentia        |1.0907238170000795|
# |59-ChromaVector4std   |1.0685475221556329|
# |30-ChromaVector9m     |0.8822011044097584|
# |61-ChromaVector6std   |0.8391218432800771|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0793799539260247
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |5-SpectralSpreadm   |2.3804399248574315|
# |41-SpectralFluxstd  |2.164947761403181 |
# |19-MFCCs11m         |2.120009681089388 |
# |66-ChromaVector11std|2.029494600815471 |
# |23-ChromaVector2m   |1.8993103606148511|
# |20-MFCCs12m         |1.8845862271054963|
# |56-ChromaVector1std |1.7480799583396198|
# |71-BPMessentia      |1.7228007383705088|
# |59-ChromaVector4std |1.681394277551927 |
# |60-ChromaVector5std |1.6280758474659653|
# |9-MFCCs1m           |1.61887535188995  |
# |62-ChromaVector7std |1.510142232606187 |
# |31-ChromaVector10m  |1.425082446087138 |
# |25-ChromaVector4m   |1.3259530941498667|
# |21-MFCCs13m         |1.3000471645346852|
# |7-SpectralFluxm     |1.2945583068309798|
# |3-EnergyEntropym    |1.182162202204286 |
# |4-SpectralCentroidm |1.1537457631253565|
# |65-ChromaVector10std|0.7462870300363028|
# |27-ChromaVector6m   |0.7163566524005034|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# LinearSVC  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# RandomForestClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +----------------------+--------------------+
# |feature               |score               |
# +----------------------+--------------------+
# |71-BPMessentia        |0.0780834385929847  |
# |69-BPM                |0.04724030518130918 |
# |70-BPMconf            |0.02793339041951445 |
# |1-ZCRm                |0.021719204823089994|
# |54-MFCCs12std         |0.02132388385616505 |
# |44-MFCCs2std          |0.021266001345583586|
# |48-MFCCs6std          |0.020809097373653277|
# |2-Energym             |0.020000194723859974|
# |39-SpectralSpreadstd  |0.01970763472160904 |
# |55-MFCCs13std         |0.01926512012337798 |
# |53-MFCCs11std         |0.018999164697007232|
# |3-EnergyEntropym      |0.018823867896738823|
# |4-SpectralCentroidm   |0.018533530173366793|
# |9-MFCCs1m             |0.018348582242687077|
# |43-MFCCs1std          |0.018212388234915885|
# |38-SpectralCentroidstd|0.0178933648084373  |
# |10-MFCCs2m            |0.015847697495014988|
# |11-MFCCs3m            |0.015107275404789566|
# |52-MFCCs10std         |0.014143506799181868|
# |50-MFCCs8std          |0.013911366970693144|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# GBTClassifier  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# DecisionTreeClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +---------------------+--------------------+
# |feature              |score               |
# +---------------------+--------------------+
# |71-BPMessentia       |0.24454827950921265 |
# |69-BPM               |0.2127621250799597  |
# |39-SpectralSpreadstd |0.09363933340435933 |
# |70-BPMconf           |0.08926440917694643 |
# |7-SpectralFluxm      |0.06311080366192896 |
# |6-SpectralEntropym   |0.0507098231563238  |
# |48-MFCCs6std         |0.03373452843270696 |
# |52-MFCCs10std        |0.030947257518916776|
# |2-Energym            |0.028565690861325165|
# |44-MFCCs2std         |0.026199779512230396|
# |3-EnergyEntropym     |0.025778553759721497|
# |50-MFCCs8std         |0.023739611456683806|
# |43-MFCCs1std         |0.022577027215219356|
# |55-MFCCs13std        |0.01717964081784719 |
# |42-SpectralRolloffstd|0.015534857050309646|
# |11-MFCCs3m           |0.011177359234827216|
# |13-MFCCs5m           |0.010530920151480976|
# |30-ChromaVector9m    |0.0                 |
# |24-ChromaVector3m    |0.0                 |
# |31-ChromaVector10m   |0.0                 |
# +---------------------+--------------------+
# only showing top 20 rows
#
# None
#
# MultilayerPerceptronClassifier
# Model Weights:  12023
#
# !!!!!Final Results!!!!!!!!
# +------------------------------+------+
# |Classifier                    |Result|
# +------------------------------+------+
# |LogisticRegression            |46.86 |
# |OneVsRest                     |47.72 |
# |LinearSVC                     |N/A   |
# |NaiveBayes                    |37.46 |
# |RandomForestClassifier        |46.58 |
# |GBTClassifier                 |N/A   |
# |DecisionTreeClassifier        |34.33 |
# |MultilayerPerceptronClassifier|43.73 |
# +------------------------------+------+

# %%
from pyspark.ml.feature import VectorSlicer
from pyspark.ml.feature import ChiSqSelector
from pyspark.ml.linalg import Vectors

classifiers = [OneVsRest()] 

#Select the top n features and view results
maximum = len(input_columns)
for n in range(10,maximum,10):
    print("Testing top n = ",n," features")
    
    # For Tree classifiers
#     best_n_features = RF_featureimportances.argsort()[-n:][::-1]
#     best_n_features= best_n_features.tolist() # convert to a list
#     vs = VectorSlicer(inputCol="features", outputCol="best_features", indices=best_n_features)
#     bestFeaturesDf = vs.transform(test2_data)

    # For Logistic regression or One vs Rest
    selector = ChiSqSelector(numTopFeatures=n, featuresCol="features",
                         outputCol="selectedFeatures", labelCol="label")
    bestFeaturesDf = selector.fit(test2_data).transform(test2_data)
    bestFeaturesDf = bestFeaturesDf.select("label","selectedFeatures")
    bestFeaturesDf = bestFeaturesDf.withColumnRenamed("selectedFeatures","features")

    # Collect features
    features = bestFeaturesDf.select(['features']).collect()

    # Split
    train,test = bestFeaturesDf.randomSplit([0.7,0.3])
    
    # Specify folds
    folds = 2

    #set up your results table
    columns = ['Classifier', 'Result']
    vals = [("Place Holder","N/A")]
    results = spark.createDataFrame(vals, columns)

    for classifier in classifiers:
        new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
        results = results.union(new_result)
    results = results.where("Classifier!='Place Holder'")
    results.show(100,False)
# Out:
# Testing top n =  10  features
#
# OneVsRest
# Intercept:  0.2637945579860772
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |10-MFCCs2m         |1.9821448878262002 |
# |8-SpectralRolloffm |0.9059107261293992 |
# |3-EnergyEntropym   |0.1836138288127672 |
# |2-Energym          |-0.6534049109311282|
# |1-ZCRm             |-1.56661149687291  |
# |6-SpectralEntropym |-1.9407641613453712|
# |7-SpectralFluxm    |-2.3157463015300856|
# |4-SpectralCentroidm|-2.5818039215518884|
# |9-MFCCs1m          |-2.712070235386066 |
# |5-SpectralSpreadm  |-4.962541388156002 |
# +-------------------+-------------------+
#
# None
# Intercept:  -5.007903261581921
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |4.2472607472003725  |
# |10-MFCCs2m         |2.5473685276021976  |
# |4-SpectralCentroidm|0.2809210002350842  |
# |6-SpectralEntropym |0.2321555919093326  |
# |1-ZCRm             |0.1834484552061521  |
# |3-EnergyEntropym   |-0.09416341959896207|
# |5-SpectralSpreadm  |-0.4366327948534584 |
# |8-SpectralRolloffm |-1.265034884567479  |
# |7-SpectralFluxm    |-1.8079825576565447 |
# |2-Energym          |-4.648725743500519  |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.4516263496259563
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |8-SpectralRolloffm |3.652751253920935   |
# |6-SpectralEntropym |1.4303037849913947  |
# |2-Energym          |1.174936582173393   |
# |1-ZCRm             |0.9378469140755525  |
# |5-SpectralSpreadm  |0.1290769544177171  |
# |3-EnergyEntropym   |-0.09856717473384705|
# |7-SpectralFluxm    |-0.8381537892888093 |
# |10-MFCCs2m         |-1.0920961342243944 |
# |4-SpectralCentroidm|-1.2246894841504483 |
# |9-MFCCs1m          |-3.250763323022009  |
# +-------------------+--------------------+
#
# None
# Intercept:  -4.488483128152144
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |5-SpectralSpreadm  |4.1264005950427665 |
# |8-SpectralRolloffm |3.1701406796866998 |
# |2-Energym          |1.8440567981603153 |
# |7-SpectralFluxm    |1.5563443206214065 |
# |3-EnergyEntropym   |0.9455422520815329 |
# |10-MFCCs2m         |0.8668061113371681 |
# |4-SpectralCentroidm|0.6161904367993722 |
# |1-ZCRm             |-0.3959783258031617|
# |6-SpectralEntropym |-2.319388897025484 |
# |9-MFCCs1m          |-4.74751641588647  |
# +-------------------+-------------------+
#
# None
# Intercept:  1.75584860924668
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |2.742444741277091  |
# |6-SpectralEntropym |2.344337013026637  |
# |9-MFCCs1m          |1.9580993210095734 |
# |1-ZCRm             |-1.3511942157251813|
# |4-SpectralCentroidm|-1.4455100870964641|
# |5-SpectralSpreadm  |-2.255115745041723 |
# |3-EnergyEntropym   |-2.623443145837438 |
# |2-Energym          |-3.6046485458268434|
# |8-SpectralRolloffm |-4.059426570139022 |
# |10-MFCCs2m         |-8.19315873171401  |
# +-------------------+-------------------+
#
# None
# Intercept:  -1.0602767597085307
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |9-MFCCs1m          |4.634926453173842  |
# |6-SpectralEntropym |2.470746082252587  |
# |1-ZCRm             |0.8231033042404767 |
# |3-EnergyEntropym   |-1.0392786675754064|
# |10-MFCCs2m         |-1.0497954105897962|
# |8-SpectralRolloffm |-2.2004430617171256|
# |2-Energym          |-3.745979894050479 |
# |7-SpectralFluxm    |-4.086038964329013 |
# |4-SpectralCentroidm|-4.5772761460829   |
# |5-SpectralSpreadm  |-4.651345715344168 |
# +-------------------+-------------------+
#
# None
# Intercept:  -1.9280158736582835
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |10-MFCCs2m         |1.9577100652728427  |
# |8-SpectralRolloffm |0.6814979413669261  |
# |1-ZCRm             |-0.09345001897787333|
# |2-Energym          |-0.13734456316244248|
# |9-MFCCs1m          |-0.28614113215777637|
# |6-SpectralEntropym |-1.20580621724642   |
# |3-EnergyEntropym   |-1.4465440836642502 |
# |4-SpectralCentroidm|-1.7053411931760916 |
# |5-SpectralSpreadm  |-2.7814454512433158 |
# |7-SpectralFluxm    |-2.9544570410656483 |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.458180810110184
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |2-Energym          |4.974283896358425  |
# |5-SpectralSpreadm  |2.997507511911932  |
# |4-SpectralCentroidm|2.125245771595999  |
# |9-MFCCs1m          |1.9234282743667634 |
# |3-EnergyEntropym   |1.3581542482413282 |
# |8-SpectralRolloffm |0.9051837402689512 |
# |7-SpectralFluxm    |0.8660375112719662 |
# |1-ZCRm             |0.25391830260364373|
# |10-MFCCs2m         |-2.4690641826894977|
# |6-SpectralEntropym |-3.540204798819488 |
# +-------------------+-------------------+
#
# None
# Intercept:  -2.9165456053687677
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |3.9401721595508414 |
# |6-SpectralEntropym |2.632875882244233  |
# |8-SpectralRolloffm |2.2370305805801505 |
# |5-SpectralSpreadm  |1.0428827888250924 |
# |1-ZCRm             |0.3624907932036695 |
# |9-MFCCs1m          |-1.2138864169352899|
# |10-MFCCs2m         |-1.37568295861983  |
# |2-Energym          |-1.498591541237583 |
# |3-EnergyEntropym   |-1.8008319840267513|
# |4-SpectralCentroidm|-2.669743959351926 |
# +-------------------+-------------------+
#
# None
# Intercept:  -2.2221140748846224
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |8-SpectralRolloffm |2.65175393225588    |
# |10-MFCCs2m         |1.897275878087576   |
# |6-SpectralEntropym |1.5231019276234035  |
# |2-Energym          |0.2618063846530823  |
# |3-EnergyEntropym   |0.13696568038037546 |
# |4-SpectralCentroidm|-0.06213920615293282|
# |1-ZCRm             |-0.6889200599425951 |
# |7-SpectralFluxm    |-0.7807831063295821 |
# |5-SpectralSpreadm  |-0.9456100736942362 |
# |9-MFCCs1m          |-4.814735777558008  |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.676933763854117
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |6-SpectralEntropym |5.348406488058503  |
# |9-MFCCs1m          |2.843240965555521  |
# |5-SpectralSpreadm  |0.8564361890059579 |
# |8-SpectralRolloffm |0.8531838347735972 |
# |7-SpectralFluxm    |0.4913672572122377 |
# |4-SpectralCentroidm|0.2509240178827095 |
# |3-EnergyEntropym   |-0.6131118630818967|
# |1-ZCRm             |-0.6802153447646947|
# |10-MFCCs2m         |-3.8628781504530787|
# |2-Energym          |-4.194579565710738 |
# +-------------------+-------------------+
#
# None
# Intercept:  -2.3219736904083055
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |8-SpectralRolloffm |2.70923554458501    |
# |10-MFCCs2m         |2.2156345582264847  |
# |2-Energym          |1.5683112247473656  |
# |9-MFCCs1m          |1.4439073970774217  |
# |4-SpectralCentroidm|1.1549669194384309  |
# |6-SpectralEntropym |-0.365193900093065  |
# |1-ZCRm             |-0.41660704225360445|
# |3-EnergyEntropym   |-0.963936529953506  |
# |7-SpectralFluxm    |-4.671906101225468  |
# |5-SpectralSpreadm  |-7.435681988594058  |
# +-------------------+--------------------+
#
# None
# Intercept:  -1.9107765459755686
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |4-SpectralCentroidm|3.26306165566792    |
# |10-MFCCs2m         |2.992800014580909   |
# |5-SpectralSpreadm  |-0.2622884182170645 |
# |1-ZCRm             |-0.42984033190196985|
# |2-Energym          |-0.6115560476444399 |
# |3-EnergyEntropym   |-2.0786522894230988 |
# |9-MFCCs1m          |-2.616585870384517  |
# |6-SpectralEntropym |-5.278323327536496  |
# |7-SpectralFluxm    |-5.308658623667788  |
# |8-SpectralRolloffm |-7.866918657601391  |
# +-------------------+--------------------+
#
# None
# Intercept:  -1.1647544467449045
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |9-MFCCs1m          |3.8858936859284614 |
# |3-EnergyEntropym   |1.2989771924441549 |
# |8-SpectralRolloffm |0.6584781290860019 |
# |5-SpectralSpreadm  |-0.9620786304532241|
# |1-ZCRm             |-1.225794521617382 |
# |10-MFCCs2m         |-1.966701639800594 |
# |6-SpectralEntropym |-1.971053581129235 |
# |7-SpectralFluxm    |-2.2198891899828084|
# |2-Energym          |-3.5541093700360977|
# |4-SpectralCentroidm|-3.838814356354671 |
# +-------------------+-------------------+
#
# None
# Intercept:  -0.1483724914689759
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |1.3419543879808171  |
# |10-MFCCs2m         |1.2733989521677187  |
# |7-SpectralFluxm    |1.159275987079238   |
# |5-SpectralSpreadm  |-0.1988402773501032 |
# |2-Energym          |-0.27129965436252734|
# |3-EnergyEntropym   |-0.8752017902324324 |
# |4-SpectralCentroidm|-1.1449665871335442 |
# |8-SpectralRolloffm |-1.1806408170966587 |
# |1-ZCRm             |-2.1437428862595787 |
# |9-MFCCs1m          |-6.727788699092539  |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.384737806107756
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |7-SpectralFluxm    |3.439053205551735   |
# |5-SpectralSpreadm  |2.830077536284694   |
# |1-ZCRm             |2.031436050166466   |
# |2-Energym          |0.8593271267234962  |
# |6-SpectralEntropym |0.13903422619327307 |
# |3-EnergyEntropym   |0.10205174639994015 |
# |4-SpectralCentroidm|-0.0538256234086185 |
# |10-MFCCs2m         |-0.19006647900585089|
# |8-SpectralRolloffm |-0.728689043783715  |
# |9-MFCCs1m          |-1.7568771762142172 |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.766789064379871
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |5-SpectralSpreadm  |6.513853681421439  |
# |10-MFCCs2m         |2.394019816506788  |
# |4-SpectralCentroidm|1.4722572527525795 |
# |3-EnergyEntropym   |0.8845127575343339 |
# |7-SpectralFluxm    |0.47660013344006313|
# |6-SpectralEntropym |-0.1367248831570583|
# |2-Energym          |-0.6775898927753495|
# |1-ZCRm             |-1.3129209542071434|
# |9-MFCCs1m          |-2.9153298148892577|
# |8-SpectralRolloffm |-4.026124406330395 |
# +-------------------+-------------------+
#
# None
# Intercept:  -4.366614321730798
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |2-Energym          |3.898352179516376  |
# |5-SpectralSpreadm  |3.1446676834002703 |
# |3-EnergyEntropym   |1.6553414938478757 |
# |1-ZCRm             |1.1057476781610676 |
# |10-MFCCs2m         |1.035660486770947  |
# |7-SpectralFluxm    |0.9958098438482397 |
# |4-SpectralCentroidm|-0.5769418952445614|
# |8-SpectralRolloffm |-1.163378876602915 |
# |9-MFCCs1m          |-4.186937930327273 |
# |6-SpectralEntropym |-4.191336942734366 |
# +-------------------+-------------------+
#
# None
# Intercept:  -9.425339612216593
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |10-MFCCs2m         |9.23437135010523    |
# |4-SpectralCentroidm|1.9165356000190883  |
# |5-SpectralSpreadm  |1.4716065317415852  |
# |9-MFCCs1m          |1.2776638387947312  |
# |3-EnergyEntropym   |1.2551157088918323  |
# |1-ZCRm             |1.0159509501473527  |
# |8-SpectralRolloffm |0.6068339973835342  |
# |2-Energym          |-0.26905042095238013|
# |7-SpectralFluxm    |-2.0695873153803452 |
# |6-SpectralEntropym |-5.100434949171928  |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.196737462681521
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |6-SpectralEntropym |6.319316582259003  |
# |5-SpectralSpreadm  |2.807275050364859  |
# |1-ZCRm             |2.455050598669039  |
# |8-SpectralRolloffm |2.145650905024194  |
# |3-EnergyEntropym   |1.8961245437771272 |
# |9-MFCCs1m          |1.2511116819843917 |
# |4-SpectralCentroidm|-0.4432121567142729|
# |7-SpectralFluxm    |-0.5909136753665291|
# |2-Energym          |-1.9658540515204415|
# |10-MFCCs2m         |-4.354206689399997 |
# +-------------------+-------------------+
#
# None
# Intercept:  -1.6877004000626374
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |2-Energym          |2.6690816973071914 |
# |7-SpectralFluxm    |2.5774672360592232 |
# |10-MFCCs2m         |1.3122883911917949 |
# |5-SpectralSpreadm  |1.0419736555956405 |
# |4-SpectralCentroidm|0.15743584023666304|
# |1-ZCRm             |-0.2918848449875956|
# |6-SpectralEntropym |-1.831941302862801 |
# |8-SpectralRolloffm |-2.4681020171605152|
# |3-EnergyEntropym   |-3.2183858270706103|
# |9-MFCCs1m          |-6.162029518776787 |
# +-------------------+-------------------+
#
# None
# Intercept:  -3.13651476583478
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |5-SpectralSpreadm  |2.3673582145531755 |
# |10-MFCCs2m         |1.791370562693895  |
# |4-SpectralCentroidm|1.0938744702638927 |
# |3-EnergyEntropym   |0.36385958554697967|
# |2-Energym          |0.1513392402150241 |
# |1-ZCRm             |-1.0353483268799435|
# |7-SpectralFluxm    |-1.3825395313622777|
# |6-SpectralEntropym |-1.9952305098931797|
# |9-MFCCs1m          |-2.5995336325143863|
# |8-SpectralRolloffm |-2.985164661127972 |
# +-------------------+-------------------+
#
# None
# Intercept:  -3.429423306861797
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |2-Energym          |6.253016207911956  |
# |10-MFCCs2m         |2.833402580477214  |
# |3-EnergyEntropym   |2.5878018661993103 |
# |1-ZCRm             |2.135396710897254  |
# |4-SpectralCentroidm|1.1263952004472755 |
# |8-SpectralRolloffm |0.8078039920061919 |
# |7-SpectralFluxm    |0.5180977351060444 |
# |9-MFCCs1m          |-2.3073559706185147|
# |6-SpectralEntropym |-3.0624057517058496|
# |5-SpectralSpreadm  |-9.881735519099156 |
# +-------------------+-------------------+
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |23.69 |
# +----------+------+
#
# Testing top n =  20  features
#
# OneVsRest
# Intercept:  -0.30002696461832423
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |3.0831346719244648 |
# |13-MFCCs5m         |2.414144507638445  |
# |20-MFCCs12m        |1.3368000263355673 |
# |16-MFCCs8m         |0.9601619514985102 |
# |4-SpectralCentroidm|0.814467399329842  |
# |6-SpectralEntropym |0.6327692372391196 |
# |17-MFCCs9m         |0.5809097937281289 |
# |3-EnergyEntropym   |0.35257671014570613|
# |12-MFCCs4m         |-0.3538036198819811|
# |11-MFCCs3m         |-1.1083646350751504|
# |2-Energym          |-1.173817234400277 |
# |5-SpectralSpreadm  |-1.176957295007242 |
# |15-MFCCs7m         |-1.2761849084035737|
# |18-MFCCs10m        |-1.3841863126752791|
# |14-MFCCs6m         |-1.7354464442871846|
# |10-MFCCs2m         |-2.0567732247687305|
# |7-SpectralFluxm    |-2.76066435384994  |
# |9-MFCCs1m          |-2.780651850593212 |
# |8-SpectralRolloffm |-3.498017516962154 |
# |19-MFCCs11m        |-3.574230727423426 |
# +-------------------+-------------------+
#
# None
# Intercept:  -7.4390039325112465
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |19-MFCCs11m        |4.182573065998964   |
# |20-MFCCs12m        |3.257846353634017   |
# |12-MFCCs4m         |2.14319157133554    |
# |18-MFCCs10m        |1.854400072334264   |
# |10-MFCCs2m         |1.722683728629109   |
# |4-SpectralCentroidm|1.6616441692688355  |
# |7-SpectralFluxm    |1.49265435970503    |
# |8-SpectralRolloffm |1.2652781230569539  |
# |6-SpectralEntropym |1.1017018930169549  |
# |11-MFCCs3m         |1.1008665765303796  |
# |2-Energym          |0.5021746219886145  |
# |13-MFCCs5m         |0.019762705024574275|
# |16-MFCCs8m         |-0.36902761720092786|
# |3-EnergyEntropym   |-0.8207017393330724 |
# |1-ZCRm             |-1.4292432746224184 |
# |5-SpectralSpreadm  |-2.027852870886767  |
# |9-MFCCs1m          |-2.5608001890155987 |
# |17-MFCCs9m         |-2.804382368173116  |
# |15-MFCCs7m         |-2.9217358634004658 |
# |14-MFCCs6m         |-3.3976780908420907 |
# +-------------------+--------------------+
#
# None
# Intercept:  -4.401429936847878
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |13-MFCCs5m         |3.2450845097142795 |
# |17-MFCCs9m         |2.2905254993320088 |
# |16-MFCCs8m         |1.6403111579542102 |
# |1-ZCRm             |1.4822128439637272 |
# |15-MFCCs7m         |1.2708996751127644 |
# |2-Energym          |1.182158974050764  |
# |8-SpectralRolloffm |1.0255874982263111 |
# |5-SpectralSpreadm  |0.8899251172041844 |
# |9-MFCCs1m          |0.5930567599824436 |
# |12-MFCCs4m         |0.43946470919747677|
# |6-SpectralEntropym |0.3350136916223924 |
# |7-SpectralFluxm    |-0.309226415578919 |
# |11-MFCCs3m         |-0.5000519717852095|
# |20-MFCCs12m        |-0.6073695909820119|
# |3-EnergyEntropym   |-0.6085881507155795|
# |14-MFCCs6m         |-0.6098741125025351|
# |10-MFCCs2m         |-0.9887678128632279|
# |18-MFCCs10m        |-1.4348653080599922|
# |4-SpectralCentroidm|-1.7244727535049913|
# |19-MFCCs11m        |-2.5277295593577205|
# +-------------------+-------------------+
#
# None
# Intercept:  -3.9503538695579232
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |17-MFCCs9m         |2.9882945877981544  |
# |9-MFCCs1m          |2.8642473128951185  |
# |8-SpectralRolloffm |2.2652593832036088  |
# |6-SpectralEntropym |2.0718322464175696  |
# |15-MFCCs7m         |1.581604313524951   |
# |18-MFCCs10m        |1.4142621554554808  |
# |16-MFCCs8m         |1.322901989988198   |
# |4-SpectralCentroidm|1.2357335071055597  |
# |20-MFCCs12m        |0.98356557964348    |
# |7-SpectralFluxm    |0.4368088809618408  |
# |13-MFCCs5m         |0.40792886852391724 |
# |5-SpectralSpreadm  |0.28144669567427844 |
# |11-MFCCs3m         |0.14401554260652388 |
# |2-Energym          |-0.05061060001611477|
# |14-MFCCs6m         |-0.43214943202549677|
# |3-EnergyEntropym   |-0.9722860480508304 |
# |12-MFCCs4m         |-1.288728700476673  |
# |10-MFCCs2m         |-3.1898395524533623 |
# |19-MFCCs11m        |-3.278372564553719  |
# |1-ZCRm             |-3.7234527840755707 |
# +-------------------+--------------------+
#
# None
# Intercept:  0.09111596533687205
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |4.235645433087448   |
# |15-MFCCs7m         |3.4657230223604096  |
# |4-SpectralCentroidm|2.8856395513717894  |
# |8-SpectralRolloffm |2.4130880811876603  |
# |14-MFCCs6m         |1.7683702843542148  |
# |19-MFCCs11m        |1.7369993145129858  |
# |11-MFCCs3m         |0.9993927963691464  |
# |7-SpectralFluxm    |-0.48894251146528833|
# |12-MFCCs4m         |-0.5930340488281971 |
# |5-SpectralSpreadm  |-0.6054847492859026 |
# |18-MFCCs10m        |-0.6456389611395467 |
# |3-EnergyEntropym   |-0.7584142270408442 |
# |16-MFCCs8m         |-0.8190519606597747 |
# |6-SpectralEntropym |-0.9995831509401455 |
# |2-Energym          |-1.5944325393271255 |
# |17-MFCCs9m         |-1.6674119658249889 |
# |10-MFCCs2m         |-2.4667098603477022 |
# |13-MFCCs5m         |-2.4715816535065316 |
# |9-MFCCs1m          |-3.3645672441977195 |
# |20-MFCCs12m        |-8.038609698533593  |
# +-------------------+--------------------+
#
# None
# Intercept:  -4.852545044751304
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |19-MFCCs11m        |4.040933546709366   |
# |4-SpectralCentroidm|3.6414791591391142  |
# |10-MFCCs2m         |2.942766484752135   |
# |18-MFCCs10m        |2.390052991576862   |
# |13-MFCCs5m         |1.568497399030163   |
# |1-ZCRm             |1.4418546660504     |
# |12-MFCCs4m         |1.202069946666415   |
# |14-MFCCs6m         |0.9489438661786931  |
# |11-MFCCs3m         |0.4804564985927002  |
# |5-SpectralSpreadm  |-0.2749083038841478 |
# |2-Energym          |-0.321587520812962  |
# |20-MFCCs12m        |-0.43908453614571813|
# |3-EnergyEntropym   |-0.5633313078744119 |
# |17-MFCCs9m         |-0.651828555342966  |
# |6-SpectralEntropym |-0.7501464198741782 |
# |16-MFCCs8m         |-1.833175670163507  |
# |8-SpectralRolloffm |-2.8455278305091634 |
# |7-SpectralFluxm    |-2.8947772525500204 |
# |15-MFCCs7m         |-4.078227395027198  |
# |9-MFCCs1m          |-4.953785855205768  |
# +-------------------+--------------------+
#
# None
# Intercept:  -4.26685095951731
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |3.676583910725215   |
# |20-MFCCs12m        |2.2838453542568957  |
# |17-MFCCs9m         |1.4308964915400268  |
# |10-MFCCs2m         |1.2325627990292805  |
# |3-EnergyEntropym   |0.8309876074923598  |
# |5-SpectralSpreadm  |0.6717566158152426  |
# |12-MFCCs4m         |0.6662356872844567  |
# |13-MFCCs5m         |0.4336102114438215  |
# |2-Energym          |0.2502520725785454  |
# |16-MFCCs8m         |-0.09429332470616619|
# |8-SpectralRolloffm |-0.3456014769945568 |
# |4-SpectralCentroidm|-0.43536876216047515|
# |11-MFCCs3m         |-0.6023881506677033 |
# |6-SpectralEntropym |-0.750727514483914  |
# |19-MFCCs11m        |-0.7642527975225952 |
# |18-MFCCs10m        |-0.8318141803167884 |
# |15-MFCCs7m         |-1.8860898520939164 |
# |14-MFCCs6m         |-2.250167192113312  |
# |9-MFCCs1m          |-2.5539483248758543 |
# |7-SpectralFluxm    |-2.7963800902511036 |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.198316634853197
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |4.951754213226369   |
# |7-SpectralFluxm    |1.621162788939903   |
# |5-SpectralSpreadm  |1.5062149079469345  |
# |19-MFCCs11m        |1.3228706727805983  |
# |4-SpectralCentroidm|1.00163006855001    |
# |16-MFCCs8m         |0.628331224121145   |
# |6-SpectralEntropym |0.5290501797449481  |
# |11-MFCCs3m         |0.4780921343018931  |
# |2-Energym          |0.44614450298022085 |
# |15-MFCCs7m         |0.40396682365883074 |
# |3-EnergyEntropym   |0.368633922272938   |
# |17-MFCCs9m         |0.20452896706504317 |
# |13-MFCCs5m         |-0.19740894422498512|
# |12-MFCCs4m         |-0.5408852643353992 |
# |14-MFCCs6m         |-1.2263317017299404 |
# |10-MFCCs2m         |-1.498285808615983  |
# |18-MFCCs10m        |-1.5519996574078332 |
# |20-MFCCs12m        |-3.089895029195864  |
# |8-SpectralRolloffm |-3.1391635673414853 |
# |1-ZCRm             |-4.132806541268726  |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.252446167293015
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |15-MFCCs7m         |3.694271231459647   |
# |12-MFCCs4m         |1.9091343632125388  |
# |11-MFCCs3m         |1.889143231586955   |
# |18-MFCCs10m        |1.8346436450996615  |
# |14-MFCCs6m         |1.4635651925911908  |
# |16-MFCCs8m         |1.1144655464408135  |
# |3-EnergyEntropym   |0.37093477736186864 |
# |17-MFCCs9m         |0.3646681583073319  |
# |2-Energym          |0.3504148463115759  |
# |9-MFCCs1m          |0.3060922550893995  |
# |13-MFCCs5m         |0.08357364394277192 |
# |8-SpectralRolloffm |-0.26473985414621204|
# |19-MFCCs11m        |-0.2829275884680578 |
# |10-MFCCs2m         |-0.42652376883083415|
# |20-MFCCs12m        |-0.9038626950875323 |
# |5-SpectralSpreadm  |-1.5759007996824876 |
# |7-SpectralFluxm    |-1.8410688358903362 |
# |6-SpectralEntropym |-3.6059016855660575 |
# |1-ZCRm             |-5.1903081776462665 |
# |4-SpectralCentroidm|-6.091268992078692  |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.425054401227737
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |3.4810911741366333  |
# |13-MFCCs5m         |3.2383709885206686  |
# |17-MFCCs9m         |2.327521119898418   |
# |20-MFCCs12m        |2.3161609093017925  |
# |8-SpectralRolloffm |1.3179909116508413  |
# |16-MFCCs8m         |1.120639138811007   |
# |5-SpectralSpreadm  |0.7805297682793395  |
# |14-MFCCs6m         |0.4732565480808342  |
# |6-SpectralEntropym |0.39620727337101813 |
# |15-MFCCs7m         |0.39057905746854443 |
# |2-Energym          |0.3655561293873444  |
# |18-MFCCs10m        |0.15465178029488116 |
# |12-MFCCs4m         |-0.14055435588144047|
# |9-MFCCs1m          |-0.21143797714121784|
# |10-MFCCs2m         |-0.477687475753691  |
# |7-SpectralFluxm    |-0.7801590733287433 |
# |3-EnergyEntropym   |-1.330357280934119  |
# |11-MFCCs3m         |-1.4706315217591426 |
# |4-SpectralCentroidm|-1.799482895435953  |
# |19-MFCCs11m        |-3.1357846726057206 |
# +-------------------+--------------------+
#
# None
# Intercept:  -3.5011379559411537
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |19-MFCCs11m        |2.860274580743555    |
# |14-MFCCs6m         |1.8731745795332322   |
# |13-MFCCs5m         |1.8635801526291649   |
# |12-MFCCs4m         |1.1961889178448237   |
# |11-MFCCs3m         |1.124444540024091    |
# |10-MFCCs2m         |0.9634288888822552   |
# |18-MFCCs10m        |0.7765628363919344   |
# |15-MFCCs7m         |0.7188621365330877   |
# |7-SpectralFluxm    |0.6689669386664906   |
# |1-ZCRm             |0.2809866854203015   |
# |8-SpectralRolloffm |0.186960906486634    |
# |6-SpectralEntropym |-0.049952867153028685|
# |9-MFCCs1m          |-0.0586649930389763  |
# |17-MFCCs9m         |-0.4879221963915295  |
# |2-Energym          |-0.7148464051316588  |
# |4-SpectralCentroidm|-0.7400616419453351  |
# |3-EnergyEntropym   |-1.5890127181813916  |
# |16-MFCCs8m         |-2.3609824958109105  |
# |5-SpectralSpreadm  |-2.407856804998401   |
# |20-MFCCs12m        |-3.662729397298352   |
# +-------------------+---------------------+
#
# None
# Intercept:  -4.221915535861574
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |3.6102064369656333  |
# |5-SpectralSpreadm  |3.0278167668542113  |
# |20-MFCCs12m        |2.7982217317114717  |
# |11-MFCCs3m         |2.334473585627669   |
# |17-MFCCs9m         |2.281962639040197   |
# |16-MFCCs8m         |1.4886103381461222  |
# |18-MFCCs10m        |1.3387540303249534  |
# |19-MFCCs11m        |1.2979949522903942  |
# |7-SpectralFluxm    |1.2473150068154817  |
# |14-MFCCs6m         |0.4468944468846271  |
# |2-Energym          |0.15581465807294595 |
# |13-MFCCs5m         |-0.09935135636220516|
# |12-MFCCs4m         |-0.13352536822661615|
# |3-EnergyEntropym   |-1.0456206485449349 |
# |6-SpectralEntropym |-1.497995619608571  |
# |4-SpectralCentroidm|-1.8839969897807791 |
# |10-MFCCs2m         |-2.7710247549955893 |
# |15-MFCCs7m         |-3.0481796147480256 |
# |8-SpectralRolloffm |-3.6264408572617164 |
# |9-MFCCs1m          |-4.985564950907657  |
# +-------------------+--------------------+
#
# None
# Intercept:  0.8775128900673499
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |2.8286605588931923 |
# |7-SpectralFluxm    |2.2697567400810734 |
# |20-MFCCs12m        |2.196824508600316  |
# |10-MFCCs2m         |1.8713787716742507 |
# |8-SpectralRolloffm |1.415973974306663  |
# |4-SpectralCentroidm|0.9776541845366151 |
# |3-EnergyEntropym   |0.9334464389490552 |
# |9-MFCCs1m          |-0.6956246177002434|
# |6-SpectralEntropym |-1.109129666230026 |
# |2-Energym          |-1.5332417380588705|
# |16-MFCCs8m         |-1.5898887862748137|
# |19-MFCCs11m        |-1.7203867973610731|
# |14-MFCCs6m         |-1.916105008292433 |
# |17-MFCCs9m         |-2.1840241483241134|
# |5-SpectralSpreadm  |-2.2093814400924843|
# |12-MFCCs4m         |-2.6696873469725917|
# |15-MFCCs7m         |-3.4284738708192837|
# |11-MFCCs3m         |-4.074265531006819 |
# |13-MFCCs5m         |-4.5667210301251115|
# |18-MFCCs10m        |-5.7971237679782925|
# +-------------------+-------------------+
#
# None
# Intercept:  -6.160437774331843
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |19-MFCCs11m        |4.186245079919271   |
# |13-MFCCs5m         |2.743909144955313   |
# |4-SpectralCentroidm|2.7360433523979557  |
# |11-MFCCs3m         |2.5301143385726177  |
# |1-ZCRm             |2.0409113171603246  |
# |6-SpectralEntropym |1.7239832536708215  |
# |12-MFCCs4m         |1.1610895107904582  |
# |16-MFCCs8m         |0.9614789992325055  |
# |3-EnergyEntropym   |0.4527650239171848  |
# |10-MFCCs2m         |0.10875830237850559 |
# |17-MFCCs9m         |-0.30506241333461553|
# |5-SpectralSpreadm  |-0.336284210182464  |
# |8-SpectralRolloffm |-0.6240186322130017 |
# |9-MFCCs1m          |-0.6478386483098214 |
# |2-Energym          |-1.056254088851692  |
# |18-MFCCs10m        |-1.4917900246755682 |
# |7-SpectralFluxm    |-1.7008669426675063 |
# |20-MFCCs12m        |-1.9430185165144682 |
# |15-MFCCs7m         |-2.109549609253506  |
# |14-MFCCs6m         |-3.5755809931466844 |
# +-------------------+--------------------+
#
# None
# Intercept:  -0.9765114258093206
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |8-SpectralRolloffm |4.1549721040217875   |
# |20-MFCCs12m        |2.0786400107957      |
# |13-MFCCs5m         |2.0186211449883635   |
# |14-MFCCs6m         |1.583654303284276    |
# |12-MFCCs4m         |0.9358697658546136   |
# |16-MFCCs8m         |0.8240959978521123   |
# |15-MFCCs7m         |0.6396151195802362   |
# |11-MFCCs3m         |-0.033936968380686015|
# |1-ZCRm             |-0.08603877540982038 |
# |18-MFCCs10m        |-0.10376455839228214 |
# |3-EnergyEntropym   |-0.40185908257705333 |
# |6-SpectralEntropym |-0.6044210060904812  |
# |5-SpectralSpreadm  |-0.911225794482159   |
# |10-MFCCs2m         |-1.3520594965895096  |
# |7-SpectralFluxm    |-1.4065612103531386  |
# |17-MFCCs9m         |-1.5310130338997505  |
# |4-SpectralCentroidm|-1.8437331984308931  |
# |9-MFCCs1m          |-2.6433815193385337  |
# |2-Energym          |-2.868134555282359   |
# |19-MFCCs11m        |-6.45126156726563    |
# +-------------------+---------------------+
#
# None
# Intercept:  -3.1488053995061738
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |9-MFCCs1m          |2.5338732588103743   |
# |18-MFCCs10m        |2.162088790163957    |
# |15-MFCCs7m         |1.9001411534406687   |
# |16-MFCCs8m         |1.3105062899145      |
# |2-Energym          |1.275012317256421    |
# |12-MFCCs4m         |0.9830887086955364   |
# |13-MFCCs5m         |0.4131313540112053   |
# |3-EnergyEntropym   |0.3703266487369692   |
# |11-MFCCs3m         |0.3278357737520197   |
# |20-MFCCs12m        |0.12017982518505613  |
# |5-SpectralSpreadm  |-0.005816091348999591|
# |10-MFCCs2m         |-0.40718321173031746 |
# |4-SpectralCentroidm|-0.498882608462751   |
# |7-SpectralFluxm    |-0.6505493376246851  |
# |14-MFCCs6m         |-0.94501387140275    |
# |6-SpectralEntropym |-0.9810751354393527  |
# |8-SpectralRolloffm |-1.2675301871855493  |
# |19-MFCCs11m        |-2.2164558370007765  |
# |17-MFCCs9m         |-2.3969992874923824  |
# |1-ZCRm             |-5.581946472735441   |
# +-------------------+---------------------+
#
# None
# Intercept:  -5.622103840940471
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |4.732911480794787   |
# |10-MFCCs2m         |3.405470993817167   |
# |20-MFCCs12m        |2.4456211917183412  |
# |7-SpectralFluxm    |1.8502242283782746  |
# |4-SpectralCentroidm|1.0916025057804482  |
# |16-MFCCs8m         |1.034996165975118   |
# |8-SpectralRolloffm |0.8505259686976113  |
# |14-MFCCs6m         |0.787069707168403   |
# |3-EnergyEntropym   |0.6481847937932839  |
# |5-SpectralSpreadm  |0.5721465912628533  |
# |6-SpectralEntropym |0.48415229553757605 |
# |11-MFCCs3m         |0.13687739411512082 |
# |15-MFCCs7m         |0.13308180323527175 |
# |1-ZCRm             |-0.38068232755772613|
# |18-MFCCs10m        |-0.44301570013217384|
# |12-MFCCs4m         |-0.9681267974657013 |
# |2-Energym          |-1.0328128497869953 |
# |19-MFCCs11m        |-2.605782728807067  |
# |17-MFCCs9m         |-3.3354641738184436 |
# |13-MFCCs5m         |-4.198862926437952  |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.1793581259826666
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |9-MFCCs1m          |3.187037915122333  |
# |16-MFCCs8m         |2.567336315248428  |
# |15-MFCCs7m         |2.512686511671616  |
# |2-Energym          |2.324069981805237  |
# |6-SpectralEntropym |1.96694171370388   |
# |5-SpectralSpreadm  |1.0380166523033418 |
# |17-MFCCs9m         |0.5441073622393543 |
# |4-SpectralCentroidm|0.489937675700084  |
# |8-SpectralRolloffm |0.46081746871467394|
# |20-MFCCs12m        |0.4213923418174585 |
# |7-SpectralFluxm    |0.05808306610229035|
# |13-MFCCs5m         |-0.474171502256896 |
# |12-MFCCs4m         |-0.5216829807986222|
# |3-EnergyEntropym   |-0.6376691789353857|
# |18-MFCCs10m        |-1.0106315578389342|
# |14-MFCCs6m         |-1.9152512677512104|
# |1-ZCRm             |-2.4244464034529143|
# |11-MFCCs3m         |-2.5283204939544692|
# |10-MFCCs2m         |-3.8588334487429927|
# |19-MFCCs11m        |-4.068606043813527 |
# +-------------------+-------------------+
#
# None
# Intercept:  -4.741266021450803
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |20-MFCCs12m        |8.641222231176446   |
# |9-MFCCs1m          |2.9538898443510666  |
# |17-MFCCs9m         |2.9211321712092544  |
# |18-MFCCs10m        |2.177506813349059   |
# |19-MFCCs11m        |2.120843545448033   |
# |6-SpectralEntropym |1.3810270325506566  |
# |16-MFCCs8m         |0.46249128331083234 |
# |2-Energym          |0.393363656886698   |
# |1-ZCRm             |-0.41255845760187543|
# |7-SpectralFluxm    |-0.42907807002471315|
# |12-MFCCs4m         |-0.5240862155719425 |
# |10-MFCCs2m         |-0.7784532141244647 |
# |3-EnergyEntropym   |-0.8470796087620048 |
# |15-MFCCs7m         |-1.8792246178120011 |
# |11-MFCCs3m         |-1.8927467408447503 |
# |5-SpectralSpreadm  |-1.9728626242945873 |
# |4-SpectralCentroidm|-2.265166245359263  |
# |14-MFCCs6m         |-3.5198392110104733 |
# |8-SpectralRolloffm |-3.52013381294726   |
# |13-MFCCs5m         |-6.00572523617097   |
# +-------------------+--------------------+
#
# None
# Intercept:  -9.083383648817119
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |13-MFCCs5m         |3.396553663440766  |
# |14-MFCCs6m         |3.2228107768444416 |
# |9-MFCCs1m          |3.0958559775219845 |
# |10-MFCCs2m         |2.696656814059066  |
# |2-Energym          |2.5109590383810825 |
# |11-MFCCs3m         |1.8770952586807987 |
# |7-SpectralFluxm    |1.2600019748790012 |
# |3-EnergyEntropym   |1.2468137551738363 |
# |12-MFCCs4m         |1.158908474152276  |
# |18-MFCCs10m        |1.099561197098999  |
# |4-SpectralCentroidm|0.8645848407260341 |
# |19-MFCCs11m        |0.7611492421187075 |
# |5-SpectralSpreadm  |0.6042357012572437 |
# |6-SpectralEntropym |0.47798195462661286|
# |17-MFCCs9m         |0.18125089405615136|
# |16-MFCCs8m         |-1.4387063915257985|
# |1-ZCRm             |-1.6116332746641873|
# |15-MFCCs7m         |-1.8510654642012565|
# |8-SpectralRolloffm |-2.0721992225882513|
# |20-MFCCs12m        |-3.0726369287956348|
# +-------------------+-------------------+
#
# None
# Intercept:  -1.2936604824955875
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |8-SpectralRolloffm |5.39742252946912    |
# |10-MFCCs2m         |2.4243682760835426  |
# |20-MFCCs12m        |1.8804179512833585  |
# |5-SpectralSpreadm  |1.5218846202492269  |
# |15-MFCCs7m         |1.2777294150533982  |
# |17-MFCCs9m         |1.0838849545644809  |
# |2-Energym          |0.3202031906116347  |
# |7-SpectralFluxm    |-0.10938319266710157|
# |11-MFCCs3m         |-0.20567782796664058|
# |4-SpectralCentroidm|-0.7539299392267192 |
# |13-MFCCs5m         |-1.1055687871207158 |
# |14-MFCCs6m         |-1.338502815218363  |
# |12-MFCCs4m         |-1.4159021720107232 |
# |3-EnergyEntropym   |-1.6386364937602402 |
# |1-ZCRm             |-1.6701796034231151 |
# |16-MFCCs8m         |-2.291674314556901  |
# |9-MFCCs1m          |-2.355156592426685  |
# |18-MFCCs10m        |-2.5940707420039777 |
# |19-MFCCs11m        |-2.957265919702688  |
# |6-SpectralEntropym |-3.6905521435617574 |
# +-------------------+--------------------+
#
# None
# Intercept:  -0.8497255576575911
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |5-SpectralSpreadm  |1.5614162948358723  |
# |8-SpectralRolloffm |1.331124558529848   |
# |7-SpectralFluxm    |1.0538646184476543  |
# |20-MFCCs12m        |1.0160177811166666  |
# |3-EnergyEntropym   |0.7814815505178221  |
# |6-SpectralEntropym |0.6364894994257455  |
# |9-MFCCs1m          |0.44042752058741946 |
# |18-MFCCs10m        |0.40200391203254104 |
# |10-MFCCs2m         |0.23471399964054881 |
# |4-SpectralCentroidm|-0.3306407265663542 |
# |11-MFCCs3m         |-0.39723012929824564|
# |14-MFCCs6m         |-0.4367616222868449 |
# |1-ZCRm             |-0.5275817575808565 |
# |15-MFCCs7m         |-0.9730040857142372 |
# |2-Energym          |-1.1826712509839503 |
# |13-MFCCs5m         |-2.0182833430487395 |
# |16-MFCCs8m         |-2.164741785493569  |
# |19-MFCCs11m        |-2.957369722571971  |
# |17-MFCCs9m         |-3.30098099229482   |
# |12-MFCCs4m         |-3.374571084094654  |
# +-------------------+--------------------+
#
# None
# Intercept:  2.6994844326135663
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |20-MFCCs12m        |2.7237503746346596  |
# |3-EnergyEntropym   |1.7953267723863253  |
# |5-SpectralSpreadm  |1.0631712114588985  |
# |6-SpectralEntropym |0.8770118470253765  |
# |15-MFCCs7m         |0.8200804077838706  |
# |2-Energym          |0.7620254609833996  |
# |14-MFCCs6m         |0.6894624858432878  |
# |13-MFCCs5m         |-0.08056753319419134|
# |7-SpectralFluxm    |-0.18119426744109596|
# |18-MFCCs10m        |-0.6450637657580345 |
# |16-MFCCs8m         |-0.7939087669860438 |
# |12-MFCCs4m         |-1.3727616130942497 |
# |17-MFCCs9m         |-1.4575307790659862 |
# |1-ZCRm             |-2.717478256524245  |
# |19-MFCCs11m        |-3.2650309741320687 |
# |4-SpectralCentroidm|-3.850381693489602  |
# |8-SpectralRolloffm |-4.033813490411569  |
# |10-MFCCs2m         |-4.830438702755473  |
# |11-MFCCs3m         |-5.047602724965085  |
# |9-MFCCs1m          |-5.350281143102181  |
# +-------------------+--------------------+
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |33.04 |
# +----------+------+
#
# Testing top n =  30  features
#
# OneVsRest
# Intercept:  -1.3595511093694057
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |22-ChromaVector1m  |2.0704347355586887  |
# |1-ZCRm             |1.8005629573781117  |
# |26-ChromaVector5m  |1.7436087552220414  |
# |8-SpectralRolloffm |1.7093500906375396  |
# |9-MFCCs1m          |1.484044183134887   |
# |30-ChromaVector9m  |1.3798679204450632  |
# |2-Energym          |1.1394578557140542  |
# |19-MFCCs11m        |0.9494294272552904  |
# |13-MFCCs5m         |0.9150942828740135  |
# |27-ChromaVector6m  |0.46017468082267915 |
# |5-SpectralSpreadm  |0.283590019389199   |
# |25-ChromaVector4m  |0.1420421472457837  |
# |11-MFCCs3m         |0.039226009196549054|
# |21-MFCCs13m        |-0.07535398200730183|
# |7-SpectralFluxm    |-0.08409032973501492|
# |14-MFCCs6m         |-0.4339685076602795 |
# |6-SpectralEntropym |-0.5273331995377456 |
# |4-SpectralCentroidm|-0.5377353493603164 |
# |24-ChromaVector3m  |-0.681636378447286  |
# |10-MFCCs2m         |-0.7207120120857297 |
# +-------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.2044300393807745
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |29-ChromaVector8m  |3.990666320209112    |
# |30-ChromaVector9m  |2.731694187694622    |
# |9-MFCCs1m          |2.5153105854753313   |
# |18-MFCCs10m        |2.185081335550541    |
# |2-Energym          |2.171698254339661    |
# |12-MFCCs4m         |1.8941621279823206   |
# |11-MFCCs3m         |1.8762808326521285   |
# |28-ChromaVector7m  |1.1784117442593731   |
# |21-MFCCs13m        |0.9430574681369439   |
# |15-MFCCs7m         |0.897758046281473    |
# |20-MFCCs12m        |0.6981223312278246   |
# |6-SpectralEntropym |0.5424022769352875   |
# |13-MFCCs5m         |0.45346465802344527  |
# |22-ChromaVector1m  |0.22497834913548403  |
# |26-ChromaVector5m  |0.022212217988415908 |
# |16-MFCCs8m         |-0.015722519559392207|
# |19-MFCCs11m        |-0.07764422976001845 |
# |25-ChromaVector4m  |-0.252648507176373   |
# |17-MFCCs9m         |-0.5818023946964638  |
# |4-SpectralCentroidm|-0.6916379102864006  |
# +-------------------+---------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.3623912871133577
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |22-ChromaVector1m  |3.2319744994757955  |
# |10-MFCCs2m         |2.1984450116308873  |
# |24-ChromaVector3m  |1.7370455645546101  |
# |25-ChromaVector4m  |1.722758215865459   |
# |8-SpectralRolloffm |1.65903188529754    |
# |27-ChromaVector6m  |1.4619095624531873  |
# |1-ZCRm             |1.1771808484533648  |
# |20-MFCCs12m        |0.9108125205417577  |
# |26-ChromaVector5m  |0.7734214181950883  |
# |21-MFCCs13m        |0.5567479889348542  |
# |15-MFCCs7m         |0.5062389968846086  |
# |16-MFCCs8m         |0.49608217992720716 |
# |6-SpectralEntropym |0.3818045466783032  |
# |4-SpectralCentroidm|0.24104055706992353 |
# |17-MFCCs9m         |0.07056036643037694 |
# |12-MFCCs4m         |0.055837702569790586|
# |28-ChromaVector7m  |0.031144915451872913|
# |5-SpectralSpreadm  |-0.20452524752579285|
# |18-MFCCs10m        |-0.26727232723481503|
# |2-Energym          |-0.3937649906848167 |
# +-------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.75052405852532
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |4-SpectralCentroidm|4.363826096266432   |
# |27-ChromaVector6m  |2.807400679217169   |
# |15-MFCCs7m         |2.715922115890646   |
# |9-MFCCs1m          |2.0761932229117774  |
# |14-MFCCs6m         |1.7260087973551261  |
# |28-ChromaVector7m  |1.4599776307901733  |
# |30-ChromaVector9m  |1.111620535091766   |
# |26-ChromaVector5m  |0.7275360063606028  |
# |24-ChromaVector3m  |0.7038339219617537  |
# |12-MFCCs4m         |0.48608331914708697 |
# |20-MFCCs12m        |0.47621348295765686 |
# |17-MFCCs9m         |0.3832886580284565  |
# |22-ChromaVector1m  |0.28893805253636184 |
# |16-MFCCs8m         |0.18419005474380773 |
# |19-MFCCs11m        |0.07631324684254653 |
# |21-MFCCs13m        |0.05562188342779955 |
# |8-SpectralRolloffm |0.011489513667827684|
# |10-MFCCs2m         |-0.0568481563871706 |
# |13-MFCCs5m         |-0.09081080148390921|
# |11-MFCCs3m         |-0.1588232746814728 |
# +-------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.3957787656559186
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |2-Energym          |4.636306170636817  |
# |1-ZCRm             |3.6211897737992005 |
# |9-MFCCs1m          |2.4192199334230278 |
# |24-ChromaVector3m  |2.2329790281836215 |
# |29-ChromaVector8m  |2.0478603974125154 |
# |4-SpectralCentroidm|1.9000160638306274 |
# |23-ChromaVector2m  |1.5864274379489338 |
# |15-MFCCs7m         |1.4869271345650807 |
# |20-MFCCs12m        |0.8908684014809733 |
# |19-MFCCs11m        |0.592241561009939  |
# |28-ChromaVector7m  |0.48256872406256435|
# |14-MFCCs6m         |0.2363685812495616 |
# |26-ChromaVector5m  |0.20236686035052906|
# |8-SpectralRolloffm |0.08527546498602206|
# |10-MFCCs2m         |-0.5318230831381617|
# |3-EnergyEntropym   |-0.5357829374686713|
# |12-MFCCs4m         |-0.548301449166723 |
# |7-SpectralFluxm    |-0.7682685967902185|
# |27-ChromaVector6m  |-0.8448163605308221|
# |5-SpectralSpreadm  |-1.0674754847824701|
# +-------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.906996969409235
# Top 20 Coefficients:
# +------------------+--------------------+
# |feature           |coeff               |
# +------------------+--------------------+
# |29-ChromaVector8m |4.502657765894499   |
# |9-MFCCs1m         |3.9142514048643253  |
# |5-SpectralSpreadm |3.515126679001194   |
# |18-MFCCs10m       |2.723494785056067   |
# |23-ChromaVector2m |1.5678104763682446  |
# |10-MFCCs2m        |1.4203597232691345  |
# |11-MFCCs3m        |1.3920467156003176  |
# |28-ChromaVector7m |1.320555911939923   |
# |2-Energym         |1.2654989165969115  |
# |21-MFCCs13m       |1.211040595543663   |
# |19-MFCCs11m       |0.8621804319170612  |
# |1-ZCRm            |0.7965986995143628  |
# |22-ChromaVector1m |0.7202223385239146  |
# |27-ChromaVector6m |0.5687841919261029  |
# |30-ChromaVector9m |0.2567903353924878  |
# |6-SpectralEntropym|0.1135389584052532  |
# |7-SpectralFluxm   |0.1005314309973504  |
# |26-ChromaVector5m |-0.04492502003946579|
# |13-MFCCs5m        |-0.27300161071710954|
# |20-MFCCs12m       |-0.47144553129091055|
# +------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.8139665635769595
# Top 20 Coefficients:
# +------------------+---------------------+
# |feature           |coeff                |
# +------------------+---------------------+
# |1-ZCRm            |3.2414821547885264   |
# |8-SpectralRolloffm|2.6023888505651773   |
# |30-ChromaVector9m |1.9019844838921969   |
# |18-MFCCs10m       |0.9881833506784122   |
# |13-MFCCs5m        |0.8009808149554138   |
# |25-ChromaVector4m |0.7570380924522546   |
# |7-SpectralFluxm   |0.5260850468287639   |
# |27-ChromaVector6m |0.5222679838326039   |
# |28-ChromaVector7m |0.5093180660583523   |
# |6-SpectralEntropym|0.4765462586571993   |
# |21-MFCCs13m       |0.32321647221396144  |
# |26-ChromaVector5m |0.2774943992230372   |
# |2-Energym         |0.2752398346951884   |
# |22-ChromaVector1m |0.21197403388494018  |
# |9-MFCCs1m         |-0.011396868948519382|
# |10-MFCCs2m        |-0.040637762364632936|
# |19-MFCCs11m       |-0.08757314329412286 |
# |17-MFCCs9m        |-0.15689097973033578 |
# ...
# |50-MFCCs8std         |0.8935837921952966|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.690470222584475
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |9-MFCCs1m             |4.5955528439875115|
# |3-EnergyEntropym      |4.173683149544191 |
# |70-BPMconf            |2.201416951679281 |
# |60-ChromaVector5std   |1.5836316993647181|
# |38-SpectralCentroidstd|1.5633284627071087|
# |57-ChromaVector2std   |1.3912218660980038|
# |58-ChromaVector3std   |1.2745693885322635|
# |62-ChromaVector7std   |1.2666975694208134|
# |36-Energystd          |1.238596691571935 |
# |43-MFCCs1std          |1.2332268273951188|
# |61-ChromaVector6std   |1.231474153977153 |
# |42-SpectralRolloffstd |1.173924576217997 |
# |2-Energym             |1.123104621713835 |
# |40-SpectralEntropystd |1.038371838134634 |
# |45-MFCCs3std          |0.9979912970079627|
# |41-SpectralFluxstd    |0.8789907590148555|
# |55-MFCCs13std         |0.851840421403598 |
# |63-ChromaVector8std   |0.8020477730623801|
# |44-MFCCs2std          |0.666804343785772 |
# |39-SpectralSpreadstd  |0.5734071117745988|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.482842341305608
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |56-ChromaVector1std  |5.676996144582581 |
# |69-BPM               |2.472199609903703 |
# |9-MFCCs1m            |2.3961488153341004|
# |43-MFCCs1std         |2.1048190058543055|
# |18-MFCCs10m          |1.6251222920134063|
# |21-MFCCs13m          |1.5723539105500546|
# |62-ChromaVector7std  |1.530465863165587 |
# |13-MFCCs5m           |1.4841781244636725|
# |45-MFCCs3std         |1.4528370553532481|
# |35-ZCRstd            |1.2414829900664546|
# |48-MFCCs6std         |1.144151968664791 |
# |58-ChromaVector3std  |1.0039095810643692|
# |49-MFCCs7std         |0.908699934977802 |
# |65-ChromaVector10std |0.8915513619039908|
# |51-MFCCs9std         |0.8667526453478476|
# |40-SpectralEntropystd|0.8217311668082594|
# |11-MFCCs3m           |0.8160603188718559|
# |53-MFCCs11std        |0.7664287300998733|
# |19-MFCCs11m          |0.7360622631394804|
# |32-ChromaVector11m   |0.6994535521009202|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.928020211593843
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |63-ChromaVector8std  |3.452850274822714  |
# |2-Energym            |3.2254191538808845 |
# |9-MFCCs1m            |2.5507259676098335 |
# |67-ChromaVector12std |2.4282825751440376 |
# |28-ChromaVector7m    |2.3410469658820947 |
# |14-MFCCs6m           |2.2135238457811215 |
# |70-BPMconf           |2.061511427137626  |
# |68-ChromaDeviationstd|2.026209253793006  |
# |52-MFCCs10std        |1.915647013426896  |
# |48-MFCCs6std         |1.802138655611243  |
# |5-SpectralSpreadm    |1.7275145638966427 |
# |46-MFCCs4std         |1.4424585178971054 |
# |15-MFCCs7m           |1.4307303510121916 |
# |69-BPM               |1.2537949329889384 |
# |3-EnergyEntropym     |1.0754506715959942 |
# |1-ZCRm               |0.8215908358047985 |
# |59-ChromaVector4std  |0.535650400104843  |
# |62-ChromaVector7std  |0.5168110259064711 |
# |18-MFCCs10m          |0.4280225312741757 |
# |49-MFCCs7std         |0.40814914895119375|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  6.797736477087981
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |2-Energym             |4.058162161792917  |
# |13-MFCCs5m            |3.110928177595365  |
# |7-SpectralFluxm       |2.6904673426204275 |
# |15-MFCCs7m            |2.675776771481579  |
# |1-ZCRm                |1.8372738742613466 |
# |45-MFCCs3std          |1.627420267726753  |
# |28-ChromaVector7m     |1.5493398781491776 |
# |70-BPMconf            |1.3712523463929833 |
# |38-SpectralCentroidstd|1.02224264544864   |
# |56-ChromaVector1std   |0.7818544861244006 |
# |66-ChromaVector11std  |0.7613637149181954 |
# |35-ZCRstd             |0.6422242017356196 |
# |11-MFCCs3m            |0.5125429160929166 |
# |21-MFCCs13m           |0.4827618631070686 |
# |29-ChromaVector8m     |0.4371135540741115 |
# |4-SpectralCentroidm   |0.3153910972956937 |
# |18-MFCCs10m           |0.29428448355879777|
# |14-MFCCs6m            |0.1991048886317193 |
# |62-ChromaVector7std   |0.1403648372554955 |
# |8-SpectralRolloffm    |0.09962685377299133|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.418926162001612
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |69-BPM              |3.664546441648708 |
# |36-Energystd        |3.633296765590511 |
# |44-MFCCs2std        |3.5301581343680075|
# |55-MFCCs13std       |3.399269836744968 |
# |3-EnergyEntropym    |2.833022324002886 |
# |27-ChromaVector6m   |2.502282656670221 |
# |54-MFCCs12std       |2.1866561466397836|
# |63-ChromaVector8std |2.046580981092193 |
# |34-ChromaDeviationm |1.8780715788410678|
# |18-MFCCs10m         |1.6986396466759748|
# |48-MFCCs6std        |1.5469419786107867|
# |52-MFCCs10std       |1.087113598361588 |
# |6-SpectralEntropym  |0.9284004827533953|
# |24-ChromaVector3m   |0.8542596135641642|
# |2-Energym           |0.7270233349459164|
# |46-MFCCs4std        |0.7054230470265478|
# |60-ChromaVector5std |0.7001308221490913|
# |29-ChromaVector8m   |0.5962796780696337|
# |66-ChromaVector11std|0.5446260382049414|
# |15-MFCCs7m          |0.4749674417705109|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.864419567006002
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |3.5025238795935554|
# |43-MFCCs1std          |2.872304208604835 |
# |11-MFCCs3m            |2.573614181481784 |
# |35-ZCRstd             |2.034474162870543 |
# |46-MFCCs4std          |2.0199253660031227|
# |70-BPMconf            |1.922894939292356 |
# |54-MFCCs12std         |1.7071817008228072|
# |25-ChromaVector4m     |1.54461941693015  |
# |17-MFCCs9m            |1.2915394443080384|
# |38-SpectralCentroidstd|1.2730669469451057|
# |63-ChromaVector8std   |1.2354011129746925|
# |9-MFCCs1m             |1.2143192974258825|
# |40-SpectralEntropystd |1.1062204113256564|
# |14-MFCCs6m            |1.0359082740590357|
# |26-ChromaVector5m     |1.0247564657967223|
# |36-Energystd          |0.9924348537786548|
# |58-ChromaVector3std   |0.9537036451025571|
# |50-MFCCs8std          |0.9351804227555451|
# |20-MFCCs12m           |0.8686786842836585|
# |59-ChromaVector4std   |0.8132035159452025|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.412355426915438
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |60-ChromaVector5std  |3.084337160915148 |
# |36-Energystd         |2.947820555238511 |
# |5-SpectralSpreadm    |2.45842274124264  |
# |30-ChromaVector9m    |2.2670587797191173|
# |37-EnergyEntropystd  |2.1418170357385264|
# |39-SpectralSpreadstd |2.091782615554055 |
# |32-ChromaVector11m   |2.0176425139818623|
# |68-ChromaDeviationstd|1.6786940495687939|
# |14-MFCCs6m           |1.555604706968946 |
# |20-MFCCs12m          |1.229087247323131 |
# |49-MFCCs7std         |1.0752783901069327|
# |58-ChromaVector3std  |1.047720986816552 |
# |47-MFCCs5std         |1.047279312166899 |
# |9-MFCCs1m            |0.9980495377910934|
# |45-MFCCs3std         |0.9340486485709457|
# |54-MFCCs12std        |0.862553489443844 |
# |10-MFCCs2m           |0.8382344844230255|
# |15-MFCCs7m           |0.8030586930423268|
# |57-ChromaVector2std  |0.7952511989802339|
# |19-MFCCs11m          |0.7516687374733864|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.2641197032493476
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |41-SpectralFluxstd    |3.891197497140067 |
# |7-SpectralFluxm       |3.1077123947991048|
# |29-ChromaVector8m     |2.8902057964550067|
# |43-MFCCs1std          |2.7733563880282035|
# |39-SpectralSpreadstd  |2.0044109201456712|
# |37-EnergyEntropystd   |1.9205429074708718|
# |38-SpectralCentroidstd|1.6085549700047674|
# |21-MFCCs13m           |1.5863746849277098|
# |70-BPMconf            |1.482132091537447 |
# |33-ChromaVector12m    |1.4598856718927913|
# |45-MFCCs3std          |1.383744430116207 |
# |23-ChromaVector2m     |1.344050594813711 |
# |25-ChromaVector4m     |1.341656896913329 |
# |47-MFCCs5std          |1.2079861405363708|
# |28-ChromaVector7m     |1.1836167052226667|
# |34-ChromaDeviationm   |1.1337192493342125|
# |44-MFCCs2std          |0.8952087370329768|
# |31-ChromaVector10m    |0.849988455256994 |
# |50-MFCCs8std          |0.637783584080113 |
# |65-ChromaVector10std  |0.6201257713466806|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.649581650893704
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |10-MFCCs2m            |2.8937407078575914|
# |41-SpectralFluxstd    |2.506679093148471 |
# |32-ChromaVector11m    |2.3236308664359804|
# |36-Energystd          |2.2337935784986236|
# |27-ChromaVector6m     |2.199225972680881 |
# |29-ChromaVector8m     |1.805483864833914 |
# |55-MFCCs13std         |1.763869721967479 |
# |38-SpectralCentroidstd|1.7128264178042862|
# |21-MFCCs13m           |1.6607849451232903|
# |17-MFCCs9m            |1.6278290087824512|
# |51-MFCCs9std          |1.6236615390330351|
# |40-SpectralEntropystd |1.1751728103591852|
# |58-ChromaVector3std   |1.167762158438473 |
# |65-ChromaVector10std  |1.1558970831320172|
# |64-ChromaVector9std   |1.0666873488072102|
# |12-MFCCs4m            |1.04036685268927  |
# |20-MFCCs12m           |1.0288526395811215|
# |70-BPMconf            |0.9822594634976369|
# |13-MFCCs5m            |0.9548048106500079|
# |39-SpectralSpreadstd  |0.9070885082769278|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  0.7652552910710853
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.066023209748231 |
# |69-BPM               |3.4714067562993662|
# |41-SpectralFluxstd   |3.009330352046993 |
# |62-ChromaVector7std  |2.5264678955044557|
# |9-MFCCs1m            |2.3098103066848727|
# |7-SpectralFluxm      |2.209140772726154 |
# |67-ChromaVector12std |2.018317923521709 |
# |68-ChromaDeviationstd|1.6919038002300986|
# |66-ChromaVector11std |1.473354625538727 |
# |29-ChromaVector8m    |1.3880712454814426|
# |63-ChromaVector8std  |1.0127859976817923|
# |17-MFCCs9m           |1.002556475803484 |
# |33-ChromaVector12m   |0.8881390712414501|
# |27-ChromaVector6m    |0.8192544138976178|
# |31-ChromaVector10m   |0.7676080604189525|
# |57-ChromaVector2std  |0.7633266156888131|
# |49-MFCCs7std         |0.6975553605511831|
# |23-ChromaVector2m    |0.6345088269279896|
# |12-MFCCs4m           |0.6036659501898237|
# |36-Energystd         |0.5665836255941153|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.362511959486943
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |47-MFCCs5std         |3.687535923565278 |
# |63-ChromaVector8std  |3.0226645733169213|
# |59-ChromaVector4std  |2.6022740543856253|
# |45-MFCCs3std         |2.272689396139495 |
# |67-ChromaVector12std |2.0820602363458938|
# |55-MFCCs13std        |2.0744786434923608|
# |66-ChromaVector11std |2.0537144423174305|
# |54-MFCCs12std        |2.0443037806580215|
# |39-SpectralSpreadstd |1.9555287154220302|
# |51-MFCCs9std         |1.7526492612229025|
# |34-ChromaDeviationm  |1.6868072007688146|
# |68-ChromaDeviationstd|1.649321141623386 |
# |11-MFCCs3m           |1.605547326901855 |
# |27-ChromaVector6m    |1.4934586373461356|
# |53-MFCCs11std        |1.3696379407032389|
# |16-MFCCs8m           |1.3384018364110621|
# |50-MFCCs8std         |1.2590028342060724|
# |12-MFCCs4m           |1.1641554543843673|
# |20-MFCCs12m          |1.1086544960815061|
# |25-ChromaVector4m    |1.0797373499803904|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.294073559128552
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |35-ZCRstd             |2.7384948218303653|
# |30-ChromaVector9m     |2.6526893986328175|
# |25-ChromaVector4m     |2.525734091082295 |
# |70-BPMconf            |2.3147966378991947|
# |43-MFCCs1std          |2.052596181825179 |
# |67-ChromaVector12std  |1.9071226529877274|
# |38-SpectralCentroidstd|1.888913959850921 |
# |17-MFCCs9m            |1.3691895851529001|
# |15-MFCCs7m            |1.3652041770990788|
# |11-MFCCs3m            |1.2402451193885722|
# |44-MFCCs2std          |1.1960547368959944|
# |23-ChromaVector2m     |1.159464746908286 |
# |41-SpectralFluxstd    |1.1296010937523226|
# |56-ChromaVector1std   |1.1122422359823523|
# |37-EnergyEntropystd   |1.0158709772463994|
# |10-MFCCs2m            |0.9202338570815807|
# |47-MFCCs5std          |0.8740455563474502|
# |65-ChromaVector10std  |0.8487145309483676|
# |28-ChromaVector7m     |0.808484303030278 |
# |16-MFCCs8m            |0.7787530227664023|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.306168732797813
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |12-MFCCs4m            |1.9791151466768306|
# |44-MFCCs2std          |1.850735429911042 |
# |65-ChromaVector10std  |1.8149579724233778|
# |18-MFCCs10m           |1.7810573703949477|
# |53-MFCCs11std         |1.7283846285796691|
# |70-BPMconf            |1.6877403035436982|
# |42-SpectralRolloffstd |1.6598033457231096|
# |22-ChromaVector1m     |1.6076607001074361|
# |38-SpectralCentroidstd|1.546881819442905 |
# |20-MFCCs12m           |1.3525524230292052|
# |41-SpectralFluxstd    |1.23188730217578  |
# |32-ChromaVector11m    |1.1376245974128036|
# |36-Energystd          |1.0937289623842703|
# |9-MFCCs1m             |0.9939008891230392|
# |28-ChromaVector7m     |0.9615218782150567|
# |45-MFCCs3std          |0.8375187863453513|
# |30-ChromaVector9m     |0.7613707630965021|
# |59-ChromaVector4std   |0.751639068290465 |
# |61-ChromaVector6std   |0.6614020524172041|
# |56-ChromaVector1std   |0.6508688801752319|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.7120090862205197
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |5-SpectralSpreadm   |2.489766021187094 |
# |56-ChromaVector1std |1.9006836249816585|
# |41-SpectralFluxstd  |1.8987544949444515|
# |66-ChromaVector11std|1.8931930242767483|
# |9-MFCCs1m           |1.8327128768168037|
# |19-MFCCs11m         |1.8087376680688263|
# |25-ChromaVector4m   |1.7777110024782798|
# |3-EnergyEntropym    |1.6926507930616752|
# |62-ChromaVector7std |1.4819196323919999|
# |21-MFCCs13m         |1.428062004229881 |
# |70-BPMconf          |1.4103326331991106|
# |23-ChromaVector2m   |1.3983250446857713|
# |31-ChromaVector10m  |1.37895505793099  |
# |60-ChromaVector5std |1.2680703323067615|
# |20-MFCCs12m         |1.1156090040709046|
# |4-SpectralCentroidm |1.0860291899342525|
# |59-ChromaVector4std |1.0771816446527736|
# |30-ChromaVector9m   |0.9504349472885586|
# |7-SpectralFluxm     |0.9301870614104066|
# |33-ChromaVector12m  |0.8925259388579123|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |42.25 |
# +----------+------+

# %%
from pyspark.ml.feature import VectorSlicer
from pyspark.ml.feature import ChiSqSelector
from pyspark.ml.linalg import Vectors

classifiers = [OneVsRest()] 

#Select the top n features and view results
n = 71

# For Logistic regression or One vs Rest
selector = ChiSqSelector(numTopFeatures=n, featuresCol="features",
                     outputCol="selectedFeatures", labelCol="label")
bestFeaturesDf = selector.fit(test2_data).transform(test2_data)
bestFeaturesDf = bestFeaturesDf.select("label","selectedFeatures")
bestFeaturesDf = bestFeaturesDf.withColumnRenamed("selectedFeatures","features")

# Collect features
features = bestFeaturesDf.select(['features']).collect()

# Split
train,test = bestFeaturesDf.randomSplit([0.7,0.3])

# Specify folds
folds = 2

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
results.show(100,False)
# Out:
#
# OneVsRest
# Intercept:  -3.9047297292103105
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |4.185849629518928 |
# |22-ChromaVector1m  |2.242537028681456 |
# |71-BPMessentia     |2.1129683986372925|
# |18-MFCCs10m        |1.7193328870988267|
# |12-MFCCs4m         |1.71614580982129  |
# |3-EnergyEntropym   |1.7070823491204694|
# |11-MFCCs3m         |1.469742911214246 |
# |5-SpectralSpreadm  |1.4141929180843464|
# |54-MFCCs12std      |1.1406409608797254|
# |53-MFCCs11std      |1.1228655357226835|
# |2-Energym          |1.0732995874249984|
# |24-ChromaVector3m  |1.071268549421721 |
# |52-MFCCs10std      |0.9524137976362416|
# |62-ChromaVector7std|0.7983182941317039|
# |63-ChromaVector8std|0.7828832757835076|
# |58-ChromaVector3std|0.6773027349964431|
# |6-SpectralEntropym |0.6398984952915698|
# |47-MFCCs5std       |0.6312692335923455|
# |51-MFCCs9std       |0.6047106792098926|
# |50-MFCCs8std       |0.5442046448238504|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.005366353788874
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |4.080549204963169 |
# |40-SpectralEntropystd|2.6760866321809686|
# |69-BPM               |2.5201684896837735|
# |44-MFCCs2std         |2.4241011578845284|
# |5-SpectralSpreadm    |2.2644753238003132|
# |28-ChromaVector7m    |2.1042145370778593|
# |49-MFCCs7std         |1.7192747145073175|
# |65-ChromaVector10std |1.6342666831373756|
# |34-ChromaDeviationm  |1.6223161948914537|
# |24-ChromaVector3m    |1.6011845461127414|
# |42-SpectralRolloffstd|1.4460903785205148|
# |11-MFCCs3m           |1.3013092778228943|
# |3-EnergyEntropym     |1.0829395006104316|
# |54-MFCCs12std        |0.9887884040766586|
# |43-MFCCs1std         |0.9520795371542793|
# |16-MFCCs8m           |0.9518616996427276|
# |29-ChromaVector8m    |0.8987590435870363|
# |61-ChromaVector6std  |0.8455261515519684|
# |46-MFCCs4std         |0.7675333129827333|
# |45-MFCCs3std         |0.6432263310039397|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.704603976622857
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |3.452955094948955 |
# |12-MFCCs4m            |3.354232340459434 |
# |36-Energystd          |2.9848347630334606|
# |51-MFCCs9std          |2.5719588323466613|
# |55-MFCCs13std         |2.0876455218119623|
# |52-MFCCs10std         |1.8777611567099792|
# |25-ChromaVector4m     |1.834970155502891 |
# |17-MFCCs9m            |1.5677627667877996|
# |67-ChromaVector12std  |1.5631210702385436|
# |63-ChromaVector8std   |1.505510516108062 |
# |29-ChromaVector8m     |1.4655415554321554|
# |60-ChromaVector5std   |1.2305827380315661|
# |40-SpectralEntropystd |1.219505112237273 |
# |22-ChromaVector1m     |1.1864239242697374|
# |39-SpectralSpreadstd  |1.184191886197634 |
# |45-MFCCs3std          |1.123791654748828 |
# |53-MFCCs11std         |1.0913619605582594|
# |38-SpectralCentroidstd|0.8781704938134476|
# |9-MFCCs1m             |0.7464763007459903|
# |10-MFCCs2m            |0.6524329716740338|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.808381523622586
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |3.6711300367203736|
# |10-MFCCs2m            |3.23875921425666  |
# |67-ChromaVector12std  |3.111793048164527 |
# |11-MFCCs3m            |2.8087049435711307|
# |70-BPMconf            |2.3401957695873588|
# |23-ChromaVector2m     |1.9653323395698061|
# |16-MFCCs8m            |1.6628202021245457|
# |50-MFCCs8std          |1.575926893350455 |
# |36-Energystd          |1.568654254529207 |
# |38-SpectralCentroidstd|1.4403385630012597|
# |55-MFCCs13std         |1.2166473858190623|
# |47-MFCCs5std          |1.1521146409450311|
# |27-ChromaVector6m     |1.031612228723752 |
# |35-ZCRstd             |0.9390608522565201|
# |71-BPMessentia        |0.9033014838609066|
# |46-MFCCs4std          |0.8615398891028206|
# |53-MFCCs11std         |0.858228473176312 |
# |64-ChromaVector9std   |0.7820758402917865|
# |32-ChromaVector11m    |0.772985947573085 |
# |24-ChromaVector3m     |0.7274638122074519|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.40477785957113
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |5-SpectralSpreadm    |4.144836348023091 |
# |2-Energym            |4.071200288487128 |
# |43-MFCCs1std         |2.6629774800343107|
# |59-ChromaVector4std  |2.350132702531289 |
# |42-SpectralRolloffstd|2.1471505130721096|
# |4-SpectralCentroidm  |2.100930546408105 |
# |10-MFCCs2m           |1.6172909530427775|
# |20-MFCCs12m          |1.5702124669177162|
# |40-SpectralEntropystd|1.4982578599919998|
# |14-MFCCs6m           |1.4981089242369452|
# |69-BPM               |1.4548034248505861|
# |23-ChromaVector2m    |1.3774367065505828|
# |24-ChromaVector3m    |1.1429800647698878|
# |60-ChromaVector5std  |1.1315986349352958|
# |44-MFCCs2std         |1.1023172567226303|
# |66-ChromaVector11std |1.0581641074078427|
# |9-MFCCs1m            |1.013023333680223 |
# |48-MFCCs6std         |0.9968127162007457|
# |34-ChromaDeviationm  |0.7986619837383223|
# |33-ChromaVector12m   |0.7831104621133989|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -8.770460041856344
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |69-BPM              |4.071969426655732 |
# |13-MFCCs5m          |3.522661731084625 |
# |34-ChromaDeviationm |3.0724798844029895|
# |24-ChromaVector3m   |2.7943272631379403|
# |8-SpectralRolloffm  |1.994357160941878 |
# |65-ChromaVector10std|1.6544145061249937|
# |47-MFCCs5std        |1.4776385344102128|
# |45-MFCCs3std        |1.4463060542302892|
# |44-MFCCs2std        |1.4158546128439533|
# |4-SpectralCentroidm |1.3516130871265797|
# |20-MFCCs12m         |1.3033063393817717|
# |3-EnergyEntropym    |1.2875311485046559|
# |12-MFCCs4m          |1.2842921856132903|
# |16-MFCCs8m          |1.1816545463175359|
# |26-ChromaVector5m   |1.138488406582495 |
# |27-ChromaVector6m   |1.0219674161414123|
# |53-MFCCs11std       |0.946103889539698 |
# |59-ChromaVector4std |0.9164982040599503|
# |30-ChromaVector9m   |0.9038973689413774|
# |50-MFCCs8std        |0.8890363602637108|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.618322506921928
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |9-MFCCs1m            |3.8208298374933465|
# |43-MFCCs1std         |3.6739522153527986|
# |71-BPMessentia       |2.657383982804322 |
# |2-Energym            |2.5590866501776666|
# |22-ChromaVector1m    |1.9343664652272088|
# |57-ChromaVector2std  |1.5482890300080814|
# |46-MFCCs4std         |1.306666231637251 |
# |37-EnergyEntropystd  |1.2421531603925653|
# |18-MFCCs10m          |1.106837225450815 |
# |6-SpectralEntropym   |1.1052828113184519|
# |51-MFCCs9std         |1.1013167605289895|
# |11-MFCCs3m           |1.0757225193081954|
# |12-MFCCs4m           |1.0246790920975617|
# |30-ChromaVector9m    |0.7862781660456116|
# |68-ChromaDeviationstd|0.7720834324895757|
# |5-SpectralSpreadm    |0.7467729005722034|
# |4-SpectralCentroidm  |0.6846050851936438|
# |3-EnergyEntropym     |0.6610936245243738|
# |31-ChromaVector10m   |0.5875396343833117|
# |58-ChromaVector3std  |0.5576461835573591|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  6.7233767015474974
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |33-ChromaVector12m   |2.3521837279941162 |
# |48-MFCCs6std         |2.1309378023481096 |
# |32-ChromaVector11m   |2.1018012650337305 |
# |26-ChromaVector5m    |1.4880229998024044 |
# |62-ChromaVector7std  |1.2693370482580597 |
# |36-Energystd         |1.1839765095478552 |
# |69-BPM               |1.0977807185568724 |
# |25-ChromaVector4m    |1.016238154376022  |
# |15-MFCCs7m           |1.0060730074226039 |
# |41-SpectralFluxstd   |0.9712745564412013 |
# |68-ChromaDeviationstd|0.8076942348689553 |
# |52-MFCCs10std        |0.7581077974159488 |
# |61-ChromaVector6std  |0.7379971423888203 |
# |10-MFCCs2m           |0.5745209093329542 |
# |30-ChromaVector9m    |0.5004124388697111 |
# |18-MFCCs10m          |0.44730324244675373|
# |34-ChromaDeviationm  |0.37733261389699024|
# |28-ChromaVector7m    |0.3628587699935927 |
# |12-MFCCs4m           |0.33523970387243074|
# |55-MFCCs13std        |0.3154507741469785 |
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -8.605064464487324
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |11-MFCCs3m           |2.926482557270733 |
# |64-ChromaVector9std  |2.7469125593870185|
# |17-MFCCs9m           |2.2262388096657784|
# |48-MFCCs6std         |2.030384325035533 |
# |40-SpectralEntropystd|1.9598879101218205|
# |62-ChromaVector7std  |1.8531540621978468|
# |68-ChromaDeviationstd|1.6992535501378716|
# |65-ChromaVector10std |1.6782420928803976|
# |55-MFCCs13std        |1.6267153599786395|
# |57-ChromaVector2std  |1.5637546163133653|
# |60-ChromaVector5std  |1.5206215957600413|
# |58-ChromaVector3std  |1.4978201176686132|
# |49-MFCCs7std         |1.49509915537331  |
# |26-ChromaVector5m    |1.4879646213004565|
# |50-MFCCs8std         |1.468847143327968 |
# |12-MFCCs4m           |1.4327523031256355|
# |67-ChromaVector12std |1.4158241159348042|
# |19-MFCCs11m          |1.2410633126581823|
# |59-ChromaVector4std  |1.2290157279809197|
# |63-ChromaVector8std  |1.057349945132209 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.76651963541008
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |9-MFCCs1m             |4.68422381888743  |
# |3-EnergyEntropym      |4.473011970233705 |
# |71-BPMessentia        |2.540167796205512 |
# |38-SpectralCentroidstd|1.794973351513832 |
# |58-ChromaVector3std   |1.7065773533332538|
# |63-ChromaVector8std   |1.6180255421081242|
# |67-ChromaVector12std  |1.609666261838057 |
# |36-Energystd          |1.472278828564303 |
# |46-MFCCs4std          |1.463206843384884 |
# |41-SpectralFluxstd    |1.4334663309965943|
# |60-ChromaVector5std   |1.3975858364291789|
# |61-ChromaVector6std   |1.3570541420290698|
# |42-SpectralRolloffstd |1.2434802081428364|
# |43-MFCCs1std          |1.190396943210612 |
# |54-MFCCs12std         |1.1593071197666438|
# |62-ChromaVector7std   |1.1047076591026916|
# |40-SpectralEntropystd |1.052569920730221 |
# |2-Energym             |0.8259849142614853|
# |55-MFCCs13std         |0.6562981249266217|
# |17-MFCCs9m            |0.6458451184249461|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.604998369459661
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |4.862286329853444 |
# |9-MFCCs1m           |2.629340343856206 |
# |50-MFCCs8std        |2.2365557927050537|
# |69-BPM              |1.6143020563747086|
# |58-ChromaVector3std |1.5640248554337797|
# |62-ChromaVector7std |1.4007400025393133|
# |18-MFCCs10m         |1.3293290744258257|
# |59-ChromaVector4std |1.272574558861963 |
# |11-MFCCs3m          |1.2434920717848261|
# |45-MFCCs3std        |1.1955752944283289|
# |41-SpectralFluxstd  |1.168533214901143 |
# |49-MFCCs7std        |1.1366700883084635|
# |66-ChromaVector11std|1.1110750368699593|
# |26-ChromaVector5m   |1.0990470652027846|
# |52-MFCCs10std       |1.0711243031189535|
# |35-ZCRstd           |1.0191657642010785|
# |43-MFCCs1std        |0.9909139244070223|
# |28-ChromaVector7m   |0.7994185363234491|
# |23-ChromaVector2m   |0.7314950249228174|
# |21-MFCCs13m         |0.6067633594678278|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.241304775739695
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.488903853003211 |
# |69-BPM               |2.0515383851117766|
# |9-MFCCs1m            |1.9945535955747504|
# |67-ChromaVector12std |1.8198018375748262|
# |63-ChromaVector8std  |1.7745343134622946|
# |13-MFCCs5m           |1.730404190921469 |
# |2-Energym            |1.6509714363724208|
# |48-MFCCs6std         |1.4763227452677063|
# |25-ChromaVector4m    |1.3850247427218707|
# |3-EnergyEntropym     |1.3594301993020916|
# |14-MFCCs6m           |1.3332552221497853|
# |5-SpectralSpreadm    |1.1954240109679586|
# |52-MFCCs10std        |1.1513676671760138|
# |58-ChromaVector3std  |1.1273520448899703|
# |68-ChromaDeviationstd|1.1107341144230722|
# |15-MFCCs7m           |1.0332734046702619|
# |16-MFCCs8m           |1.0245261205187446|
# |47-MFCCs5std         |0.9016914104680345|
# |49-MFCCs7std         |0.8871359801015501|
# |28-ChromaVector7m    |0.6599530158008872|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  6.004716789244649
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |70-BPMconf            |3.604105445472866  |
# |2-Energym             |3.290225127672208  |
# |45-MFCCs3std          |2.0807949890207764 |
# |1-ZCRm                |2.067038882110457  |
# |7-SpectralFluxm       |1.8192935337736609 |
# |13-MFCCs5m            |1.4636800842809101 |
# |15-MFCCs7m            |1.413969043748285  |
# |38-SpectralCentroidstd|1.2856745121929265 |
# |44-MFCCs2std          |1.1704814333955817 |
# |56-ChromaVector1std   |0.876241131648734  |
# |71-BPMessentia        |0.7859477678229188 |
# |28-ChromaVector7m     |0.6726529056163896 |
# |30-ChromaVector9m     |0.6527246153103218 |
# |35-ZCRstd             |0.5717854298341395 |
# |18-MFCCs10m           |0.5439388314881617 |
# |8-SpectralRolloffm    |0.511997931985269  |
# |62-ChromaVector7std   |0.4771178584519732 |
# |4-SpectralCentroidm   |0.38200465982136605|
# |19-MFCCs11m           |0.367844311951246  |
# |24-ChromaVector3m     |0.34055566664099185|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.6309817424080388
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |44-MFCCs2std       |3.3318795675828303 |
# |36-Energystd       |3.2393417638950206 |
# |69-BPM             |3.1624129785199813 |
# |55-MFCCs13std      |2.854181195544086  |
# |27-ChromaVector6m  |2.5535360019529825 |
# |3-EnergyEntropym   |2.092093171098139  |
# |34-ChromaDeviationm|1.855468882423607  |
# |63-ChromaVector8std|1.8475325579999857 |
# |52-MFCCs10std      |1.4855936874001516 |
# |18-MFCCs10m        |1.4471465869054243 |
# |48-MFCCs6std       |1.415541040503844  |
# |14-MFCCs6m         |1.2104851069191656 |
# |54-MFCCs12std      |1.1212659136826457 |
# |24-ChromaVector3m  |0.9314812126613387 |
# |6-SpectralEntropym |0.7698745756251866 |
# |2-Energym          |0.7259239906178906 |
# |30-ChromaVector9m  |0.5990789832936826 |
# |46-MFCCs4std       |0.5675274463270971 |
# |53-MFCCs11std      |0.3337059436199189 |
# |64-ChromaVector9std|0.26370975885603215|
# +-------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.601581732534358
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |4.211396068596292 |
# |35-ZCRstd             |2.651542397887334 |
# |46-MFCCs4std          |2.49394086157763  |
# |9-MFCCs1m             |2.202033964268505 |
# |11-MFCCs3m            |2.141961563617333 |
# |71-BPMessentia        |1.9709853771243613|
# |14-MFCCs6m            |1.7460253512309394|
# |43-MFCCs1std          |1.6618498134777797|
# |40-SpectralEntropystd |1.5425471308097864|
# |32-ChromaVector11m    |1.415269621342299 |
# |25-ChromaVector4m     |1.3932636155570008|
# |21-MFCCs13m           |1.2204039903258845|
# |38-SpectralCentroidstd|1.163334814082647 |
# |63-ChromaVector8std   |1.1395039399915645|
# |13-MFCCs5m            |1.133576519120357 |
# |59-ChromaVector4std   |1.0023701523847084|
# |64-ChromaVector9std   |0.9809054955626758|
# |17-MFCCs9m            |0.9778182787157967|
# |44-MFCCs2std          |0.8692193749873774|
# |1-ZCRm                |0.7840739957645625|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -8.182077015663907
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |39-SpectralSpreadstd |2.8035059650014444|
# |36-Energystd         |2.589169577152818 |
# |37-EnergyEntropystd  |2.5719900056003238|
# |58-ChromaVector3std  |2.2187114939665107|
# |60-ChromaVector5std  |2.159900114527469 |
# |68-ChromaDeviationstd|1.892785952796874 |
# |49-MFCCs7std         |1.8701209498336242|
# |11-MFCCs3m           |1.8204904606914256|
# |43-MFCCs1std         |1.8054699828181509|
# |23-ChromaVector2m    |1.6841689983792087|
# |15-MFCCs7m           |1.5995510360614749|
# |32-ChromaVector11m   |1.5823580700145463|
# |9-MFCCs1m            |1.4411757077651597|
# |5-SpectralSpreadm    |1.4172658666764208|
# |18-MFCCs10m          |1.285182680322034 |
# |20-MFCCs12m          |1.2549435177019168|
# |53-MFCCs11std        |1.2263315377402302|
# |47-MFCCs5std         |1.1958244920425465|
# |63-ChromaVector8std  |1.1917119801765628|
# |30-ChromaVector9m    |1.1776882684001901|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.483534902839427
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |4.288089571058429 |
# |43-MFCCs1std          |3.361109623380768 |
# |41-SpectralFluxstd    |3.2313804441128813|
# |7-SpectralFluxm       |2.8508007522431003|
# |21-MFCCs13m           |2.306629993717977 |
# |71-BPMessentia        |2.0412447204684865|
# |23-ChromaVector2m     |1.92339903411284  |
# |38-SpectralCentroidstd|1.8870876215990353|
# |39-SpectralSpreadstd  |1.570393694771114 |
# |59-ChromaVector4std   |1.5227234013915762|
# |27-ChromaVector6m     |1.3097980384805084|
# |33-ChromaVector12m    |1.2256167854458642|
# |28-ChromaVector7m     |1.142255269095619 |
# |45-MFCCs3std          |1.1381254974225288|
# |44-MFCCs2std          |1.0689630035733033|
# |15-MFCCs7m            |1.046881323539903 |
# |32-ChromaVector11m    |1.0007313945042697|
# |48-MFCCs6std          |0.993773992325959 |
# |25-ChromaVector4m     |0.9341518252841208|
# |13-MFCCs5m            |0.8834556926880073|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.696717872466218
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |10-MFCCs2m            |2.4733483409979677|
# |17-MFCCs9m            |2.1969603945890186|
# |32-ChromaVector11m    |2.1310131799248087|
# |41-SpectralFluxstd    |1.9152319331730236|
# |36-Energystd          |1.745952889041392 |
# |38-SpectralCentroidstd|1.6353395538413902|
# |12-MFCCs4m            |1.3804220000702927|
# |26-ChromaVector5m     |1.2913315038502295|
# |21-MFCCs13m           |1.2306293208765178|
# |27-ChromaVector6m     |1.2205960179472595|
# |50-MFCCs8std          |1.1998382287078457|
# |70-BPMconf            |1.1670209250975732|
# |63-ChromaVector8std   |1.1306218119483542|
# |54-MFCCs12std         |1.0744670141202677|
# |71-BPMessentia        |1.0724049909398652|
# |55-MFCCs13std         |1.0519777528644627|
# |58-ChromaVector3std   |1.0172456397867404|
# |64-ChromaVector9std   |1.0154682913661481|
# |42-SpectralRolloffstd |0.9370358732959477|
# |65-ChromaVector10std  |0.9201745911796324|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  1.1579311738439335
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |6.657663546460789 |
# |7-SpectralFluxm      |3.501591309030539 |
# |29-ChromaVector8m    |3.184749335322806 |
# |41-SpectralFluxstd   |3.1416569178097684|
# |9-MFCCs1m            |2.7161873274392137|
# |69-BPM               |2.5771014047556644|
# |66-ChromaVector11std |2.3535173923276993|
# |62-ChromaVector7std  |2.2133450793756366|
# |68-ChromaDeviationstd|1.7772625946547393|
# |67-ChromaVector12std |1.6488547322427378|
# |31-ChromaVector10m   |1.5483108493211146|
# |63-ChromaVector8std  |1.3205491926107102|
# |57-ChromaVector2std  |1.24486290944789  |
# |33-ChromaVector12m   |1.091128505161153 |
# |17-MFCCs9m           |1.0313568064807552|
# |49-MFCCs7std         |0.9916736243949427|
# |23-ChromaVector2m    |0.924395083083172 |
# |12-MFCCs4m           |0.7177429898912854|
# |47-MFCCs5std         |0.7147154047412412|
# |61-ChromaVector6std  |0.6414290826444188|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.069839072070204
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |47-MFCCs5std         |3.4491335803728362|
# |39-SpectralSpreadstd |3.172769116281052 |
# |54-MFCCs12std        |2.390259984729324 |
# |59-ChromaVector4std  |2.374772121317974 |
# |66-ChromaVector11std |2.369293304237327 |
# |20-MFCCs12m          |2.2908226739168844|
# |55-MFCCs13std        |2.28113933558305  |
# |27-ChromaVector6m    |1.6876376366924082|
# |45-MFCCs3std         |1.5965388596809134|
# |25-ChromaVector4m    |1.5895506828598496|
# |37-EnergyEntropystd  |1.3976675273645829|
# |12-MFCCs4m           |1.3452330102666097|
# |63-ChromaVector8std  |1.319514800930068 |
# |67-ChromaVector12std |1.2591735239293915|
# |62-ChromaVector7std  |1.1546750045690268|
# |68-ChromaDeviationstd|1.1290440143220528|
# |69-BPM               |1.1008205038565357|
# |51-MFCCs9std         |1.0411465769666675|
# |16-MFCCs8m           |0.9966527739590925|
# |50-MFCCs8std         |0.9467384904446626|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.884206623793729
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |35-ZCRstd             |2.6978613927228254|
# |43-MFCCs1std          |2.124958285361445 |
# |38-SpectralCentroidstd|1.7797889828353302|
# |41-SpectralFluxstd    |1.6829287400568853|
# |11-MFCCs3m            |1.6805662234364667|
# |37-EnergyEntropystd   |1.5074626112451153|
# |25-ChromaVector4m     |1.4623192369384523|
# |71-BPMessentia        |1.4364839866430983|
# |42-SpectralRolloffstd |1.4358178517033204|
# |47-MFCCs5std          |1.367237720447998 |
# |15-MFCCs7m            |1.2346629514715164|
# |16-MFCCs8m            |1.1860449262177477|
# |56-ChromaVector1std   |1.0225777762259547|
# |10-MFCCs2m            |0.9008916695206823|
# |17-MFCCs9m            |0.8814544879472402|
# |13-MFCCs5m            |0.8047454237083708|
# |67-ChromaVector12std  |0.5874345794653233|
# |28-ChromaVector7m     |0.5804336721732651|
# |40-SpectralEntropystd |0.5381121130124255|
# |26-ChromaVector5m     |0.5269286487973837|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.1764939820216536
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |65-ChromaVector10std  |2.877030106759403 |
# |22-ChromaVector1m     |2.492264986511751 |
# |36-Energystd          |2.195300118970632 |
# |30-ChromaVector9m     |1.7970089856761313|
# |55-MFCCs13std         |1.725275976825634 |
# |44-MFCCs2std          |1.6452259738305444|
# |19-MFCCs11m           |1.543135873167152 |
# |71-BPMessentia        |1.542895562633484 |
# |38-SpectralCentroidstd|1.3545126807551415|
# |42-SpectralRolloffstd |1.2422864338333093|
# |21-MFCCs13m           |1.1425647997082995|
# |12-MFCCs4m            |1.1347367998021953|
# |18-MFCCs10m           |1.0390227891500614|
# |41-SpectralFluxstd    |1.0181252369387852|
# |7-SpectralFluxm       |0.974148273353592 |
# |33-ChromaVector12m    |0.8890345375771286|
# |9-MFCCs1m             |0.8853679809457015|
# |28-ChromaVector7m     |0.8507989353444401|
# |66-ChromaVector11std  |0.7263281086005368|
# |56-ChromaVector1std   |0.6614267020490452|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.8763859742496978
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |5-SpectralSpreadm   |2.3567928291416376|
# |66-ChromaVector11std|2.318713807854115 |
# |59-ChromaVector4std |1.9121733130721688|
# |19-MFCCs11m         |1.8623962790347244|
# |71-BPMessentia      |1.715850305071817 |
# |21-MFCCs13m         |1.6615458164887134|
# |56-ChromaVector1std |1.603287871117453 |
# |25-ChromaVector4m   |1.5785398115182356|
# |60-ChromaVector5std |1.4180513883851773|
# |3-EnergyEntropym    |1.417539490510357 |
# |4-SpectralCentroidm |1.3253611441265392|
# |62-ChromaVector7std |1.3132531804062617|
# |41-SpectralFluxstd  |1.2631555857960133|
# |16-MFCCs8m          |1.2409175252573796|
# |30-ChromaVector9m   |1.2357475368051976|
# |33-ChromaVector12m  |1.2287875159667494|
# |7-SpectralFluxm     |1.0806434897082369|
# |65-ChromaVector10std|1.0498464757856876|
# |9-MFCCs1m           |1.0490880217340945|
# |20-MFCCs12m         |0.8317330843792444|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |46.17 |
# +----------+------+

# %%
predictions = OVR_BestModel.transform(test)

# %%
# From the output earlier we saw that the new label for BigRoom is now 21.0
# Let's get a song from there
count = predictions.filter("label!=21.0 AND prediction == 21.0").count()
print(count)
predictions.filter("label!=21.0 AND prediction == 21.0").show()
# predictions.show()
# Out:
# 11
# +-----+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|prediction|
# +-----+--------------------+--------------------+----------+
# |  1.0|[0.23439685430221...|[-3.9066832886448...|      21.0|
# |  1.0|[0.34746761558915...|[-3.8610247292709...|      21.0|
# |  3.0|[0.17495648917143...|[-3.1524086070662...|      21.0|
# |  6.0|[0.27692463079165...|[-4.6682077266719...|      21.0|
# |  9.0|[0.34635321819729...|[-2.3178524858804...|      21.0|
# | 16.0|[0.17345429813292...|[-8.3841335950446...|      21.0|
# | 16.0|[0.24582293877877...|[-4.2369452225033...|      21.0|
# | 16.0|[0.34345894073264...|[-5.1095628232206...|      21.0|
# | 17.0|[0.16983627790932...|[-7.4040761608274...|      21.0|
# | 18.0|[0.32659039393572...|[-5.5452023538191...|      21.0|
# | 20.0|[0.45256871026397...|[-7.3214545084438...|      21.0|
# +-----+--------------------+--------------------+----------+

# %% [markdown]
# ### Summary statistics for numeric variables

# %%
# numeric_features = [t[0] for t in df.dtypes if t[1] == 'int' or t[1] == 'double']
# df.select(numeric_features).describe().toPandas().transpose()

# %% [markdown]
# ### Preparing Data for Machine Learning

# %%
# categoricalColumns = []

# stages = []

# for categoricalCol in categoricalColumns:
#     stringIndexer = StringIndexer(inputCol = categoricalCol, outputCol = categoricalCol + 'Index')
#     encoder = OneHotEncoderEstimator(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "classVec"])
#     stages += [stringIndexer, encoder]
    
# label_stringIdx = StringIndexer(inputCol = 'class', outputCol = 'label')

# stages += [label_stringIdx]

# numericCols = [
#     '1-ZCRm',
#     '2-Energym',
#     '3-EnergyEntropym',
#     '4-SpectralCentroidm',
#     '5-SpectralSpreadm',
#     '6-SpectralEntropym',
#     '7-SpectralFluxm',
#     '8-SpectralRolloffm',
#     '9-MFCCs1m',
#     '22-ChromaVector1m',
#     '34-ChromaDeviationm',
#     '35-ZCRstd',
#     '36-Energystd',
#     '37-EnergyEntropystd',
#     '38-SpectralCentroidstd',
#     '39-SpectralSpreadstd',
#     '40-SpectralEntropystd',
#     '41-SpectralFluxstd',
#     '42-SpectralRolloffstd',
#     '43-MFCCs1std',
#     '56-ChromaVector1std',
#     '68-ChromaDeviationstd',
#     '69-BPM',
#     '70-BPMconf',
#     '71-BPMessentia'
# ]
# assemblerInputs = [c + "classVec" for c in categoricalColumns] + numericCols

# assembler = VectorAssembler(inputCols=assemblerInputs, outputCol = "features")

# stages += [assembler]

# %% [markdown]
# ### Pipeline

# %%
# pipeline = Pipeline(stages = stages)
# pipelineModel = pipeline.fit(df)
# df = pipelineModel.transform(df)
# selectedCols = ['label', 'features'] + cols
# df = df.select(selectedCols)

# %%
# pd.DataFrame(df.take(5), columns = df.columns).transpose()

# %% [markdown]
# ### Randomly split data into train and test sets

# %%
# train, test = df.randomSplit([0.7, 0.3], seed = 40)
# print("Training Dataset Count: " + str(train.count()))
# print("Test Dataset Count: " + str(test.count()))

# %% [markdown]
# ### Define the evaluator

# %%
# evaluator = MulticlassClassificationEvaluator(predictionCol = "prediction")

# %% [markdown]
# ### Logistic Regression Model

# %%
# lr = LogisticRegression()
# lrModel = lr.fit(train)

# # Set up parameter Grid
# paramGrid = (ParamGridBuilder()
#              .addGrid(lr.regParam, [0.1, 0.3, 0.5])
#              .addGrid(lr.elasticNetParam, [0.0, 0.1, 0.2])
#              .addGrid(lrModel.maxIter, [10, 20, 50])
#              .build())

# # Cross Val score set up with all parameters
# cv = CrossValidator(estimator = lr, estimatorParamMaps = paramGrid, evaluator = evaluator, numFolds = 5)

# # Then fit the model
# cvModel = cv.fit(train)

# # Collect the best Model
# BestModel = cvModel.bestModel

# # Generate predictions
# predictions = cvModel.transform(test)

# # Print the accuracy rate of the model or AUC for a binary classifier
# print('Accuracy : {}'.format(evaluator.evaluate(predictions)))

# %%
# # Load the Summary
# trainingSummary = BestModel.summary

# # Generate confusion matrix and print (includes accuracy)
# accuracy = trainingSummary.accuracy
# falsePositiveRate = trainingSummary.weightedFalsePositiveRate
# truePositiveRate = trainingSummary.weightedTruePositiveRate
# fMeasure = trainingSummary.weightedFMeasure()
# precision = trainingSummary.weightedPrecision
# recall = trainingSummary.weightedRecall

# print("Accuracy: %s\nFPR: %s\nTPR: %s\nF-measure: %s\nPrecision: %s\nRecall: %s"
#       % (accuracy, falsePositiveRate, truePositiveRate, fMeasure, precision, recall))

# %% [markdown]
# ### Random Forest

# %%
# rf = RandomForestClassifier()
# rfModel = rf.fit(train)

# # Set up parameter Grid
# paramGrid = (ParamGridBuilder()
#              .addGrid(rf.maxDepth, [2, 5, 10])
#              .build())

# # Cross Val score set up with all parameters
# cv = CrossValidator(estimator = rf, estimatorParamMaps = paramGrid, evaluator = evaluator, numFolds = 5)

# # Then fit the model
# cvModel = cv.fit(train)

# # Collect the best Model
# BestModel = cvModel.bestModel

# # Generate predictions
# predictions = cvModel.transform(test)

# # Print the accuracy rate of the model or AUC for a binary classifier
# print('Accuracy : {}'.format(evaluator.evaluate(predictions)))

# %%
# # Load the Summary
# trainingSummary = BestModel.summary

# # Generate confusion matrix and print (includes accuracy)
# accuracy = trainingSummary.accuracy
# falsePositiveRate = trainingSummary.weightedFalsePositiveRate
# truePositiveRate = trainingSummary.weightedTruePositiveRate
# fMeasure = trainingSummary.weightedFMeasure()
# precision = trainingSummary.weightedPrecision
# recall = trainingSummary.weightedRecall

# print("Accuracy: %s\nFPR: %s\nTPR: %s\nF-measure: %s\nPrecision: %s\nRecall: %s"
#       % (accuracy, falsePositiveRate, truePositiveRate, fMeasure, precision, recall))
